# %% [markdown]
# <a href="https://colab.research.google.com/github/ParitoshP702/Bilevel-Optimization/blob/main/Genetic_Algorithm(CIFAR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd
from tqdm import tqdm
import random

# %%
pip install gurobipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gurobipy
#   Downloading gurobipy-10.0.0-cp38-cp38-manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 52.7 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-10.0.0

# %%
import gurobipy as gp

# %%
params = {
"WLSACCESSID": '753e7886-7142-449d-8baa-d41ca78716ef',
"WLSSECRET": '880d2525-364b-41d0-ac23-6dcf7ad15312',
"LICENSEID": 914249,
}
env = gp.Env(params=params)

# Create the model within the Gurobi environment
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 914249
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in

# %%
(X_train,Y_train),(X_test,Y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
train_count = 3500
eval_count = 1000
test_count = 1000

# %%
X_train = X_train/255.0
X_test  = X_test/255.0

# %%
x_train = X_train[:train_count,:,:,:]
x_eval = X_train[train_count:train_count+eval_count,:,:,:]
y_train = Y_train[:train_count]
y_eval = Y_train[train_count:train_count+eval_count]

# %%
x_test = X_test[:test_count,:,:,:]
y_test = Y_test[:test_count]

# %%
#Flattening our datasets
x_train = x_train.reshape(x_train.shape[0],-1)
x_eval = x_eval.reshape(x_eval.shape[0],-1)
x_test = x_test.reshape(x_test.shape[0],-1)

# %%
y_training = np.zeros(shape = (len(y_train),10), dtype = float)#one hot encoding the training labels
for i in range(len(y_train)):
  for j in range(10):
    if j  == y_train[i]:
      y_training[i][j] = 1.0
    else:
      y_training[i][j] = 0.0

# %%
y_val_array = np.zeros(shape = (len(y_eval),10),dtype  =float)#one hot encoding the validation labels
for i in range(len(y_eval)):
  for j in range(10):
    if j  == y_eval[i]:
      y_val_array[i][j] = 1.0
    else:
      y_val_array[i][j] = 0.0

# %%
y_testing = np.zeros(shape = (len(y_test),10),dtype  =float)#one hot encoding the validation labels
for i in range(len(y_test)):
  for j in range(10):
    if j  == y_test[i]:
      y_testing[i][j] = 1.0
    else:
      y_testing[i][j] = 0.0

# %%
loss_object = tf.keras.losses.CategoricalCrossentropy()

# %%
def complete_weight_array(model):
  weights_list = []
  for i in range(len(model.weights)):
    weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
    if i%2 == 0:
      shape_array = weights_array.shape
      for j in range(shape_array[0]):
        for k in range(shape_array[1]):
          weights_list.append(weights_array[j][k])
          # if len(weights_list_new) < skip_length:
          #   weights_list_new.append(0)
          # else:
          #   weights_list_new.append(weights_array[j][k])
    else:
      lgt = weights_array.shape[0]
      for j in range(lgt):
        weights_list.append(weights_array[j])
        # if len(weights_list_new) < skip_length:
        #   weights_list_new.append(0)
        # else:
        #   weights_list_new.append(weights_array[j])
  return np.array(weights_list)

# %%
def weight_array_for_hessian(model):
  skip_length = len(model.layers[0].weights[0].numpy().reshape(-1)) + len(model.layers[0].weights[1].numpy().reshape(-1))
  weights_list = []
  for i in range(len(model.weights)):
    weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
    if i%2 == 0:
      shape_array = weights_array.shape
      for j in range(shape_array[0]):
        for k in range(shape_array[1]):
          # weights_list.append(weights_array[j][k])
          if len(weights_list) < skip_length:
            weights_list.append(0)
          else:
            weights_list.append(weights_array[j][k])
    else:
      lgt = weights_array.shape[0]
      for j in range(lgt):
        # weights_list.append(weights_array[j])
        if len(weights_list) < skip_length:
          weights_list.append(0)
        else:
          weights_list.append(weights_array[j])
  return np.array(weights_list)

# %%
def compute_gradient(x_target,y_target,model):##general function which returns the list of gradient vector as an numpy array
  with tf.GradientTape() as tape:
    loss_object = tf.keras.losses.MeanSquaredError()
    y_pred_array = model(x_target,training = True)
    loss = loss_object(y_target,y_pred_array)
  g = tape.gradient(loss,model.trainable_variables)
  final_grad_list = []
  for i in range(len(g)):
    grad_array = tf.make_ndarray(tf.make_tensor_proto(g[i]))
    if i%2==0:
      grad_shape = grad_array.shape
      for j in range(grad_shape[0]):
        for k in range(grad_shape[1]):
          final_grad_list.append(grad_array[j][k])
    else:
      length = grad_array.shape[0]
      for j in range(length):
        final_grad_list.append(grad_array[j])
  return np.array(final_grad_list)

# %%
def compute_hessian(model):
  final_hessian_list = []
  with tf.GradientTape(persistent = True) as tape1:
    with tf.GradientTape(persistent = True) as tape2:
      loss_object = tf.keras.losses.CategoricalCrossentropy()
      y_pred_array = model(x_train,training = True)
      loss = loss_object(y_training,y_pred_array)
    g = tape2.gradient(loss, model.trainable_variables)
  for i in range(len(g)):
    # reshaped_grad = tf.reshape(g[i], [-1])
    h = tape1.jacobian(g[i],model.trainable_variables)
    final_hessian_list.append(h)


  ##Now this final hessian list is actually a double dimensional list of tensors, so we will convert it into a matrix
  #reshaping the double dimensional list of tensors into a matrix
  hessian_matrix = np.empty(shape = (1,1),dtype = float)
  for i in range(len(final_hessian_list)):
    hess_col_mat = np.empty(shape = (1,1),dtype = float)
    for j in range(len(final_hessian_list[i])):
      hess_array = tf.make_ndarray(tf.make_tensor_proto(final_hessian_list[i][j]))
      hess_shape = hess_array.shape
      if i%2 == 0:
        if j%2 == 0:
          hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2]*hess_shape[3])
        else:
          hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2])
      else:
        if j%2 == 0:
          hess_array = hess_array.reshape(hess_shape[0],hess_shape[1]*hess_shape[2])
        else:
          hess_array = hess_array
      if j==0 :
        hess_col_mat = hess_array
      else:
        hess_col_mat = np.concatenate((hess_col_mat,hess_array),axis = 1)
    if i==0:
      hessian_matrix = hess_col_mat
    else:
      hessian_matrix= np.concatenate((hessian_matrix,hess_col_mat),axis = 0)


  return hessian_matrix

# %%
def perform_fine_tuning(model,params_model):
  number_of_layers = params_model[1]
  reg_param = params_model[3]
  neurons_per_layer = params_model[0]
  activation_fun = params_model[2]

  ###calculating the hessian for the model and the gradient of the validation loss
  hessian_matrix = compute_hessian(model)
  grad_validation = compute_gradient(x_eval,y_val_array,model)
  final_weights_array_new = weight_array_for_hessian(model)
  l = len(final_weights_array_new)


  ##adding the regularization term in the hessian
  weight_array_vec = final_weights_array_new.reshape(l,1)/len(y_train)
  hessian_col_mat = np.concatenate((weight_array_vec,hessian_matrix),axis = 1)
  weight_array_withreg = np.concatenate(([[0]],final_weights_array_new.reshape(1,l)),axis = 1)/len(y_train)
  hessian_mat_with_reg = np.concatenate((weight_array_withreg,hessian_col_mat),axis = 0)


  grad_validation_new = np.concatenate(([[0]],grad_validation.reshape(1,l)),axis = 1)#validation array with regularization


  ##Solving the linear program
  ub = [10 for i in range(l+1)]
  lb = []
  for i in range(l+1):
    if i==0:
      lb.append(1e-5)
    else:
      lb.append(-10)


  # Create the model within the Gurobi environment
  m = gp.Model(env=env)
  # m = gp.Model()
  x = m.addMVar((l+1,),lb = lb, ub = ub )
  m.setObjective(grad_validation_new@x)
  # m.addConstr(hessian_mat_with_reg@x == 0)
  m.addConstr(hessian_mat_with_reg@x <= 0.1)
  m.addConstr(hessian_mat_with_reg@x >= -0.1)
  x.PStart = np.zeros(l+1)
  # GRBModel.Set(Pstart = np.zeros(l+1))
  m.optimize()
  all_vars = m.getVars()
  values = m.getAttr("x",all_vars)
  values = np.array(values)
  values = values/np.linalg.norm(values)

  final_weights_array = complete_weight_array(model)
  weight_array_with_reg = np.concatenate(([[reg_param]],final_weights_array.reshape(1,l)),axis = 1).reshape(-1)
  descent_factors = []
  for i in range(-100,20000,200):
    descent_factors.append(i*1e-3)
  descent_factors = np.array(descent_factors)


  weight_sample_space_matrix = np.empty(shape = (len(descent_factors),len(weight_array_with_reg)),dtype = float)##initializing the weight sample space matrix
  for i in range(len(descent_factors)):
    weight_sample_space_matrix[i] =weight_array_with_reg+ values*descent_factors[i]   ##assigning values to the weight sample space matrix


  ##defining the loss object
  loss_object = tf.keras.losses.CategoricalCrossentropy()

  ##computation for validation loss
  def validation_loss_computation(weight_and_reg_array):##function which computes the loss score of the model corresponding to given weights

      model_demo = Sequential()
      model_demo.add(Dense(units = 2, input_dim = 3072))
      for i in range(number_of_layers):
          model_demo.add(Dense(units = neurons_per_layer, activation = activation_fun, kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
      model_demo.add(Dense(units = 10,activation = "softmax", kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
      model_demo.compile(loss = "mean_squared_error", optimizer = "Adam", metrics = ["accuracy"])
      weight_tracker = 1##as "weight_and_reg_array" is a one dimensional array it keeps track of the indices of the array
      for i in range(len(model_demo.layers)):##changing the weights of the model layer wise
        orignal_weight_list = model.layers[i].weights
        array_1 = orignal_weight_list[0].numpy()##array corresponding to the weight matrix
        array_2 = orignal_weight_list[1].numpy()##array corresponding to the bias vector
        array_1_new = weight_and_reg_array[weight_tracker:weight_tracker+array_1.shape[0]*array_1.shape[1]]
        weight_tracker += array_1.shape[0]*array_1.shape[1]##updating the weight tracker
        array_2_new = weight_and_reg_array[weight_tracker:weight_tracker + array_2.shape[0]]
        weight_tracker += array_2.shape[0] #updating the weight tracker
        array_1_new = array_1_new.reshape(array_1.shape) ##new weight matrix
        array_2_new = array_2_new.reshape(array_2.shape) ##new bias vector
        list_of_new_array = [] ##list of the new weight matrix and the new bias vector
        list_of_new_array.append(array_1_new)
        list_of_new_array.append(array_2_new)
        model_demo.layers[i].set_weights(list_of_new_array) ##appending the new weights into the given layer of the model
      y_pred_array = model_demo(np.array(x_eval),training = False)
      y_pred_training = model_demo(np.array(x_train),training = False)
      loss = loss_object(y_val_array,y_pred_array)
      loss_t = loss_object(y_training,y_pred_training)
      # loss1,_ = model_demo.evaluate(x_eval,y_eval,verbose= 0)
      # loss2,_= model_demo.evaluate(x_train,y_train,verbose = 0)
      return loss,loss_t,model_demo


  loss_array_valid = np.empty(shape = len(descent_factors),dtype = float)##array to contain the training losses
  loss_array_train = np.empty(shape = len(descent_factors),dtype = float)##array to contain the validation losses

  for i in range(len(loss_array_valid)):
    loss_array_valid[i] ,loss_array_train[i],_= validation_loss_computation(weight_sample_space_matrix[i])


  ideal_weight_array = weight_sample_space_matrix[loss_array_valid.argmin()]
  ideal_regularization_parameter = ideal_weight_array[0]
  _,_,best_model = validation_loss_computation(ideal_weight_array)

  return ideal_weight_array[0],best_model,loss_array_valid.min()

# %%
def hyperparameters(returnAs='vals'):
    parameters = {}

    #Add other parameters here

    parameters["neurons_per_layer"] = [5,10,15]
    parameters["number_of_layers"] = [1, 2, 3]
    parameters["activation_function"] = ['relu', 'tanh', 'sigmoid']
    parameters["regularization_parameter"] = [1e-10,1e-9,1e-8]
    #Search over regularization parameter as well
    #parameters["regularization"] = []

    #Keep the last one as optimizer
    #parameters["optimization_method"] = ['adam', 'rmsprop']
    # parameters["optimization_method"] = ['adam']

    if returnAs == 'dict': return(parameters)
    if returnAs == 'vals': return(list(parameters.values()))
    if returnAs == 'keys': return(list(parameters.keys()))

# def hyperparameters_old():
#     parameters = []
#     units_per_layer = [5, 10, 15]
#     layers = [1, 2, 3]
#     activation = ['relu', 'tanh', 'sigmoid']
#     optimizer = ['adam', 'rmsprop']
#     parameters.append(units_per_layer)
#     parameters.append(layers)
#     parameters.append(activation)
#     parameters.append(optimizer)

#     return(parameters)

# %%
def generate_population(size):
    parameters = hyperparameters()

    population = []
    i=0
    while i < size:
        individual = [random.choice(parameters[j]) for j in range(len(parameters))]
        if individual not in population:
            population.append(individual)
            i+=1
    return(population)

# %%
generate_population(10)
# Out:
# [[5, 2, 'relu', 1e-08],
#  [10, 2, 'sigmoid', 1e-10],
#  [15, 1, 'tanh', 1e-09],
#  [15, 3, 'tanh', 1e-09],
#  [10, 1, 'tanh', 1e-09],
#  [15, 3, 'relu', 1e-08],
#  [5, 1, 'sigmoid', 1e-09],
#  [5, 3, 'relu', 1e-10],
#  [10, 2, 'tanh', 1e-10],
#  [15, 2, 'sigmoid', 1e-10]]

# %%
def new_child(parent1, parent2):
    parent_size = len(parent1)
    rint = random.randint(0, parent_size)
    #child = [random.choice([parent1[i],parent2[i]]) for i in range(parent_size)]
    child1 = parent1[:rint]+parent2[rint:]
    child2 = parent2[:rint]+parent1[rint:]
    child = random.choice([child1,child2])

    return(child)

# %%
def mutation(population):
    parameters = hyperparameters()
    for chromosome in population:
        if random.random() < 0.1 :
            key = random.choice(range(len(parameters)))
            parameters = hyperparameters()
            mutate_key = random.choice(parameters[key])
            chromosome[key] = mutate_key

    return(population)

# %%
def train_model(parameters,initialWeights=None):
    neurons_per_layer = parameters[0]
    no_of_layers = parameters[1]
    activation_function = parameters[2]

    #Following is not used here
    # optimization_method = parameters[3]
    regularization_param = parameters[3]

    model = Sequential()
    model.add(Dense(units=2, input_dim=3072))

    for _ in range(no_of_layers):
        model.add(Dense(units=neurons_per_layer, activation=activation_function,kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))

    model.add(Dense(units = 10,  activation = 'softmax',kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))




    return(model)

def evaluate_model(individual,initialWeights=None):
    model = train_model(individual,initialWeights)

    #The last element in the individual should always be the optimizer
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer="Adam", metrics=['accuracy'])
    model.fit(x_train, y_training, batch_size = 64, epochs = 10)

    # print("Training Accuracy:", model.evaluate(x_train, y_train, verbose = 0)[1])

    #Evaluate on evaluation data
    # loss_score, accuracy_score = model.evaluate(x_eval, y_val_array, verbose = 0)
    y_pred = model(x_eval,training = False)
    loss_score = loss_object(y_pred,y_val_array)
    return loss_score,model

# %%
generations = 5
population_size = 10

initial_population = generate_population(population_size)
losses = []
models = []
# losses = [evaluate_model(individual) for individual in initial_population]
for individual in initial_population:
  loss,model = evaluate_model(individual)
  losses.append(loss)
  models.append(model)
for i in range(len(models)):
  initial_population[i][3],models[i],losses[i] = perform_fine_tuning(models[i],initial_population[i])
# Out:
# Epoch 1/10
# 55/55 [==============================] - 4s 3ms/step - loss: 2.3611 - accuracy: 0.1254
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2790 - accuracy: 0.1654
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1952 - accuracy: 0.1923
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1235 - accuracy: 0.2143
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0862 - accuracy: 0.2163
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0511 - accuracy: 0.2269
# Epoch 7/10
# 55/55 [==============================] - 0s 5ms/step - loss: 2.0230 - accuracy: 0.2340
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0043 - accuracy: 0.2309
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9754 - accuracy: 0.2543
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9590 - accuracy: 0.2577
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2826 - accuracy: 0.1177
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1726 - accuracy: 0.1689
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1163 - accuracy: 0.1786
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0649 - accuracy: 0.1894
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0618 - accuracy: 0.1837
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0466 - accuracy: 0.1891
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0347 - accuracy: 0.2051
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0252 - accuracy: 0.2137
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0249 - accuracy: 0.2091
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0414 - accuracy: 0.1954
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2749 - accuracy: 0.1331
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2383 - accuracy: 0.1429
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2171 - accuracy: 0.1426
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1901 - accuracy: 0.1491
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1714 - accuracy: 0.1520
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1585 - accuracy: 0.1651
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1493 - accuracy: 0.1729
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1412 - accuracy: 0.1880
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1313 - accuracy: 0.1831
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1213 - accuracy: 0.1860
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.3454 - accuracy: 0.1029
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.3047 - accuracy: 0.0920
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2892 - accuracy: 0.1229
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2733 - accuracy: 0.1669
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2487 - accuracy: 0.1689
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2143 - accuracy: 0.1723
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1787 - accuracy: 0.1717
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1398 - accuracy: 0.1657
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1108 - accuracy: 0.1797
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0885 - accuracy: 0.1954
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.3042 - accuracy: 0.0977
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2981 - accuracy: 0.1083
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2803 - accuracy: 0.1071
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2332 - accuracy: 0.1634
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1948 - accuracy: 0.1691
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1490 - accuracy: 0.1691
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1247 - accuracy: 0.1720
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1039 - accuracy: 0.1834
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0931 - accuracy: 0.1843
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0676 - accuracy: 0.1860
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.3287 - accuracy: 0.1266
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2359 - accuracy: 0.1994
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.
nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.19s
#
# Barrier statistics:
#  AA' NZ     : 2.110e+07
#  Factor NZ  : 2.110e+07 (roughly 180 MB of memory)
#  Factor Ops : 9.139e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.31244308e+00 -2.95477461e+02  4.98e+04 2.78e-17  1.35e+01    40s
#    1   3.37222247e-02 -7.57751723e+01  1.79e+03 1.10e-15  1.59e+00    45s
#    2  -4.18052525e-02 -4.51841632e+00  2.76e+02 9.78e-16  8.91e-02    51s
#    3  -3.58198683e-01 -1.02769068e+00  2.96e+01 2.61e-15  1.32e-02    56s
#    4  -5.47411743e-01 -8.16483202e-01  1.16e+01 9.16e-16  5.30e-03    62s
#    5  -6.25785700e-01 -7.41908584e-01  4.74e+00 1.02e-15  2.29e-03    68s
#    6  -6.50888446e-01 -7.12241297e-01  2.52e+00 7.63e-16  1.21e-03    73s
#
# Barrier performed 6 iterations in 77.79 seconds (71.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2875   -6.7925884e-01   0.000000e+00   0.000000e+00     85s
#
# Solved in 2875 iterations and 84.74 seconds (82.59 work units)
# Optimal objective -6.792588422e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 12564 rows, 6282 columns and 76707022 nonzeros
# Model fingerprint: 0x2b859dff
# Coefficient statistics:
#   Matrix range     [1e-06, 4e+00]
#   Objective range  [3e-07, 3e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 176 rows and 4 columns (presolve time = 6s) ...
# Presolve removed 176 rows and 87 columns (presolve time = 23s) ...
# Presolve removed 176 rows and 87 columns (presolve time = 25s) ...
# Presolve removed 6370 rows and 87 columns
# Presolve time: 26.88s
# Presolved: 6194 rows, 12389 columns, 38359538 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.17s
#
# Barrier statistics:
#  AA' NZ     : 1.918e+07
#  Factor NZ  : 1.919e+07 (roughly 160 MB of memory)
#  Factor Ops : 7.923e+10 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -5.15016770e+00 -6.63178680e+01  2.05e+04 1.67e-16  6.99e+00    38s
#    1  -2.20102205e-01 -3.98153344e+01  8.13e+02 1.21e-15  9.72e-01    43s
#
# Barrier performed 1 iterations in 43.94 seconds (41.52 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      730   -4.1984425e-01   0.000000e+00   0.000000e+00     51s
#
# Solved in 730 iterations and 50.52 seconds (39.17 work units)
# Optimal objective -4.198442546e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 93327862 nonzeros
# Model fingerprint: 0xf0c4dff4
# Coefficient statistics:
#   Matrix range     [1e-11, 1e-01]
#   Objective range  [3e-08, 6e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 12s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 28s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 42s) ...
# Presolve removed 6832 rows and 0 columns
# Presolve time: 45.80s
# Presolved: 6832 rows, 13664 columns, 46670763 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 2.333e+07
#  Factor NZ  : 2.334e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.063e+11 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3.64719012e+00 -2.19276859e+01  4.07e+02 7.90e-14  9.46e-01    60s
#
# Barrier performed 0 iterations in 64.20 seconds (41.75 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      849   -3.6205033e-01   0.000000e+00   0.000000e+00     71s
#
# Solved in 849 iterations and 71.05 seconds (42.28 work units)
# Optimal objective -3.620503312e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 12564 rows, 6282 columns and 77998530 nonzeros
# Model fingerprint: 0xd1b19106
# Coefficient statistics:
#   Matrix range     [1e-11, 2e+01]
#   Objective range  [3e-09, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 76 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 76 rows and 34 columns (presolve time = 26s) ...
# Presolve removed 76 rows and 34 columns (presolve time = 36s) ...
# Presolve removed 6320 rows and 34 columns (presolve time = 40s) ...
# Presolve removed 6320 rows and 34 columns
# Presolve time: 41.12s
# Presolved: 6244 rows, 12492 columns, 38993015 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.17s
#
# Barrier statistics:
#  AA' NZ     : 1.949e+07
#  Factor NZ  : 1.950e+07 (roughly 160 MB of memory)
#  Factor Ops : 8.117e+10 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.89789760e+00 -1.31832038e+02  3.58e+05 0.00e+00  1.32e+01    51s
#
# Barrier performed 0 iterations in 54.01 seconds (42.14 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      652   -4.3046049e-01   3.531724e-06   9.387531e+07     64s
# Extra simplex iterations after uncrush: 1
#      653   -4.3046049e-01   0.000000e+00   0.000000e+00     65s
#
# Solved in 653 iterations and 64.94 seconds (43.29 work units)
# Optimal objective -4.304604862e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 12504 rows, 6252 columns and 78150422 nonzeros
# Model fingerprint: 0x8cc85483
# Coefficient statistics:
#   Matrix range     [5e-10, 6e-01]
#   Objective range  [7e-08, 1e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 23s) ...
# Presolve removed 6252 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 6252 rows and 0 columns
# Presolve time: 25.97s
# Presolved: 6252 rows, 12504 columns, 39081463 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 1.954e+07
#  Factor NZ  : 1.955e+07 (roughly 160 MB of memory)
#  Factor Ops : 8.148e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -5.08235843e-01 -6.16949802e+01  5.96e+02 6.66e-14  1.90e+00    37s
#    1  -9.68609682e-02 -1.10524915e+01  1.17e-11 1.54e-13  2.24e-01    42s
#    2  -5.05146647e-01 -2.17088006e+00  1.41e-11 1.20e-13  3.41e-02    47s
#    3  -9.56703404e-01 -1.38105622e+00  7.62e-11 1.20e-13  8.69e-03    51s
#    4  -1.09338723e+00 -1.27969950e+00  7.94e-11 1.44e-13  3.81e-03    56s
#    5  -1.17060065e+00 -1.22569066e+00  8.49e-11 1.29e-13  1.13e-03    61s
#    6  -1.20275863e+00 -1.21050653e+00  1.03e-10 1.61e-13  1.59e-04    66s
#    7  -1.20578470e+00 -1.20768525e+00  1.53e-10 1.85e-13  3.89e-05    71s
#    8  -1.20700132e+00 -1.20716136e+00  3.64e-10 1.66e-13  3.28e-06    77s
#    9  -1.20708352e+00 -1.20713828e+00  9.63e-10 1.58e-13  1.12e-06    82s
#   10  -1.20711683e+00 -1.20712897e+00  6.71e-09 1.49e-13  2.49e-07    87s
#   11  -1.20712683e+00 -1.20712781e+00  1.67e-08 1.93e-13  2.00e-08    93s
#   12  -1.20712752e+00 -1.20712756e+00  5.95e-10 1.78e-13  9.24e-10   100s
#   13  -1.20712755e+00 -1.20712755e+00  2.07e-09 1.58e-13  2.53e-11   110s
#
# Barrier solved model in 13 iterations and 110.30 seconds (87.19 work units)
# Optimal objective -1.20712755e+00
#
# Crossover log...
#
#      307 DPushes remaining with DInf 0.0000000e+00               112s
#        0 DPushes remaining with DInf 0.0000000e+00               113s
#
#        7 PPushes remaining with PInf 0.0000000e+00               114s
#        0 PPushes remaining with PInf 0.0000000e+00               114s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.8000338e-12    114s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      317   -1.2071275e+00   0.000000e+00   0.000000e+00    122s
#
# Solved in 317 iterations and 121.87 seconds (91.59 work units)
# Optimal objective -1.207127547e+00
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 12564 rows, 6282 columns and 78902462 nonzeros
# Model fingerprint: 0x8f3cdbd6
# Coefficient statistics:
#   Matrix range     [7e-10, 6e-01]
#   Objective range  [6e-08, 1e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 6282 rows and 0 columns
# Presolve time: 22.65s
# Presolved: 6282 rows, 12564 columns, 39457513 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 1.973e+07
#  Factor NZ  : 1.973e+07 (roughly 170 MB of memory)
#  Factor Ops : 8.266e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.00865972e+00 -1.13371851e+02  6.17e+02 1.78e-15  3.47e+00    34s
#    1  -5.90523347e-02 -1.49296191e+01  1.43e-11 7.73e-14  3.03e-01    39s
#    2  -4.46963839e-01 -2.52110622e+00  1.96e-11 8.88e-14  4.23e-02    43s
#    3  -9.60565991e-01 -1.46749088e+00  8.66e-11 8.50e-14  1.03e-02    48s
#    4  -1.13496431e+00 -1.30301452e+00  1.17e-10 9.06e-14  3.42e-03    53s
#    5  -1.20431182e+00 -1.24635560e+00  1.08e-10 8.40e-14  8.57e-04    58s
#    6  -1.22109225e+00 -1.22729478e+00  1.59e-10 1.04e-13  1.26e-04    63s
#    7  -1.22413872e+00 -1.22475752e+00  3.92e-10 8.39e-14  1.26e-05    68s
#    8  -1.22443411e+00 -1.22452521e+00  1.09e-09 1.17e-13  1.86e-06    73s
#    9  -1.22446944e+00 -1.22450494e+00  2.14e-09 8.44e-14  7.23e-07    78s
#   10  -1.22448871e+00 -1.22449465e+00  5.72e-09 1.12e-13  1.21e-07    83s
#   11  -1.22449261e+00 -1.22449307e+00  3.02e-10 9.77e-14  9.44e-09    89s
#   12  -1.22449289e+00 -1.22449290e+00  4.57e-10 9.24e-14  3.23e-10    96s
#   13  -1.22449290e+00 -1.22449290e+00  2.41e-10 9.45e-14  6.22e-12   104s
#
# Barrier solved model in 13 iterations and 104.33 seconds (86.37 work units)
# Optimal objective -1.22449290e+00
#
# Crossover log...
#
#      405 DPushes remaining with DInf 0.0000000e+00               106s
#        0 DPushes remaining with DInf 0.0000000e+00               109s
#
#        6 PPushes remaining with PInf 0.0000000e+00               109s
#        0 PPushes remaining with PInf 0.0000000e+00               109s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.6995170e-12    109s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      414   -1.2244929e+00   0.000000e+00   0.000000e+00    118s
#
# Solved in 414 iterations and 117.54 seconds (92.56 work units)
# Optimal objective -1.224492895e+00
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 93327862 nonzeros
# Model fingerprint: 0xd4f92987
# Coefficient statistics:
#   Matrix range     [1e-10, 1e-01]
#   Objective range  [4e-10, 5e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 12s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 29s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 42s) ...
# Presolve removed 6832 rows and 0 columns
# Presolve time: 45.61s
# Presolved: 6832 rows, 13664 columns, 46670763 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 2.333e+07
#  Factor NZ  : 2.334e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.063e+11 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.04755522e-01 -2.22346433e+01  1.64e+02 3.29e-14  9.77e-01    61s
#
# Barrier performed 0 iterations in 64.17 seconds (41.72 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      972   -3.7541149e-01   0.000000e+00   0.000000e+00     71s
#
# Solved in 972 iterations and 70.84 seconds (43.22 work units)
# Optimal objective -3.754114854e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13184 rows, 6592 columns and 86884342 nonzeros
# Model fingerprint: 0x006a9e6e
# Coefficient statistics:
#   Matrix range     [1e-11, 1e-01]
#   Objective range  [4e-08, 6e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 23s) ...
# Presolve removed 6592 rows and 0 columns
# Presolve time: 25.73s
# Presolved: 6592 rows, 13184 columns, 43448763 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.22s
#
# Barrier statistics:
#  AA' NZ     : 2.172e+07
#  Factor NZ  : 2.173e+07 (roughly 180 MB of memory)
#  Factor Ops : 9.551e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.70173737e+00 -2.81464789e+01  3.13e+02 5.68e-14  1.17e+00    39s
#    1   3.73291735e-01 -9.73027470e+00  2.35e+01 1.51e-13  2.06e-01    45s
#
# Barrier performed 1 iterations in 46.35 seconds (39.65 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1183   -5.8790008e-01   0.000000e+00   0.000000e+00     53s
#
# Solved in 1183 iterations and 52.80 seconds (42.47 work units)
# Optimal objective -5.879000816e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 12504 rows, 6252 columns and 78150418 nonzeros
# Model fingerprint: 0xebf0b2ba
# Coefficient statistics:
#   Matrix range     [1e-12, 1e-01]
#   Objective range  [2e-09, 3e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 28s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 39s) ...
# Presolve removed 2 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 6253 rows and 0 columns
# Presolve time: 42.85s
# Presolved: 6251 rows, 12503 columns, 39081355 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 1.953e+07
#  Factor NZ  : 1.954e+07 (roughly 160 MB of memory)
#  Factor Ops : 8.144e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 52.06 seconds (31.51 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      217   -1.3389547e-01   0.000000e+00   0.000000e+00     58s
#
# Solved in 217 iterations and 58.10 seconds (31.35 work units)
# Optimal objective -1.338954712e-01

# %%
# generation_wise_best_loss = []

# %%
print(initial_population)
print(losses)
# Out:
# [[15, 1, 'sigmoid', 8.484527069257649e-08], [15, 3, 'relu', 0.07474082851512698], [5, 3, 'relu', 8.24731542010705e-08], [15, 3, 'sigmoid', 8.174188065172276e-08], [5, 3, 'relu', 9.243049043134073e-08], [5, 2, 'tanh', 0.0631767487548697], [5, 3, 'tanh', 7.216560929843531e-08], [15, 3, 'sigmoid', 7.18342904381602e-08], [15, 2, 'sigmoid', 0.07816582018745337], [5, 2, 'sigmoid', 0.14067856106187268]]
# [1.8675769567489624, 1.9467943906784058, 2.069425582885742, 2.050471305847168, 2.031968832015991, 1.8606630563735962, 1.8620715141296387, 2.053598642349243, 1.9604575634002686, 2.217613697052002]

# %%
#Append fitness to population
population_with_fitness = [pop+[f] for pop,f in zip(initial_population,losses)]

#Write the generation steps here
for _ in tqdm(range(generations)):
    #Includes start as well as end while generating random integers
    r1 = random.randint(0, population_size-1)
    r2 = random.randint(0, population_size-1)

    parent1 = population_with_fitness[r1][0:-1]
    parent2 = population_with_fitness[r2][0:-1]

    number_of_offspring = 2
    offspring = [new_child(parent1,parent2) for i in range(number_of_offspring)]
    offspring = mutation(offspring)

    offspring_losses = []
    offspring_models = []

    for individual in offspring:
      loss,model = evaluate_model(individual)
      offspring_losses.append(loss)
      offspring_models.append(model)
    for i in range(len(offspring_losses)):
      offspring[i][3],offspring_models[i],offspring_losses[i] = perform_fine_tuning(offspring_models[i],offspring[i])
    # offspring_fitness = [evaluate_model(individual) for individual in offspring]

    offspring_with_fitness = [pop+[f] for pop,f in zip(offspring,offspring_losses)]

    population_with_fitness.extend(offspring_with_fitness)

    #Sort in descending by fitness
    population_with_fitness.sort(key = lambda i: i[-1])

    #Keep the best members
    population_with_fitness = population_with_fitness[0:population_size]
    # generation_wise_best_loss.append(population_with_fitness[0][-1].numpy())

best_individual = population_with_fitness[0][0:-1]
best_fitness = population_with_fitness[0][-1]
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.3032 - accuracy: 0.1191
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2556 - accuracy: 0.1451
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1743 - accuracy: 0.2051
# Epoch 4/10
# 55/55 [==============================] - 0s 4ms/step - loss: 2.1011 - accuracy: 0.2091
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0354 - accuracy: 0.2246
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9920 - accuracy: 0.2474
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9720 - accuracy: 0.2620
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9423 - accuracy: 0.2643
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9281 - accuracy: 0.2671
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9159 - accuracy: 0.2751
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2845 - accuracy: 0.1257
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2498 - accuracy: 0.1714
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2123 - accuracy: 0.1774
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1795 - accuracy: 0.1894
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1377 - accuracy: 0.1991
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0994 - accuracy: 0.2094
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0630 - accuracy: 0.2297
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0262 - accuracy: 0.2431
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0076 - accuracy: 0.2463
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9851 - accuracy: 0.2611
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 91257796 nonzeros
# Model fingerprint: 0x93692715
# Coefficient statistics:
#   Matrix range     [3e-13, 1e+00]
#   Objective range  [4e-08, 3e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 148 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 148 rows and 72 columns (presolve time = 12s) ...
# Presolve removed 148 rows and 72 columns (presolve time = 25s) ...
# Presolve removed 148 rows and 72 columns (presolve time = 26s) ...
# Presolve removed 6906 rows and 72 columns
# Presolve time: 29.94s
# Presolved: 6758 rows, 13518 columns, 45629103 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.22s
#
# Barrier statistics:
#  AA' NZ     : 2.283e+07
#  Factor NZ  : 2.284e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.029e+11 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.43729400e+00 -1.67139179e+02  1.10e+03 1.78e-15  4.75e+00    46s
#    1  -9.69383396e-02 -1.36123290e+01  2.72e+01 6.66e-14  2.66e-01    55s
#    2  -6.48515714e-01 -1.87529321e+00  2.19e+00 7.90e-14  2.34e-02    65s
#    3  -1.01139071e+00 -1.50263716e+00  1.03e+00 8.64e-14  9.36e-03    74s
#    4  -1.16578969e+00 -1.40233214e+00  5.09e-01 9.41e-14  4.51e-03    84s
#    5  -1.22826340e+00 -1.35273942e+00  2.89e-01 7.37e-14  2.37e-03    93s

#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 21s) ...
# Presolve removed 6282 rows and 0 columns
# Presolve time: 23.94s
# Presolved: 6282 rows, 12564 columns, 39457513 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.25s
#
# Barrier statistics:
#  AA' NZ     : 1.973e+07
#  Factor NZ  : 1.973e+07 (roughly 170 MB of memory)
#  Factor Ops : 8.266e+10 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.86971094e+00 -8.34818358e+01  2.75e+02 4.44e-16  3.36e-01    35s
#    1  -6.43256141e-03 -1.31421922e+01  2.97e+00 2.93e-14  3.37e-02    40s
#    2  -1.94172958e-01 -1.87612656e+00  3.56e-01 3.55e-14  4.28e-03    45s
#    3  -4.13855938e-01 -1.07274312e+00  1.78e-01 3.33e-14  1.68e-03    49s
#    4  -5.70900422e-01 -8.19321319e-01  7.61e-02 2.82e-14  6.32e-04    54s
#    5  -6.52089907e-01 -7.49670078e-01  2.21e-02 2.75e-14  2.48e-04    60s
#    6  -6.81535710e-01 -7.12752729e-01  4.95e-03 3.55e-14  7.94e-05    65s
#
# Barrier performed 6 iterations in 66.73 seconds (52.93 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2525   -6.9205029e-01   0.000000e+00   0.000000e+00     72s
#
# Solved in 2525 iterations and 72.04 seconds (59.18 work units)
# Optimal objective -6.920502887e-01
#  40%|████      | 2/5 [10:45<15:36, 312.10s/it]
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 5.3101 - accuracy: 0.0969
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 4.4003 - accuracy: 0.1549
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 3.7454 - accuracy: 0.1837
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 3.2824 - accuracy: 0.1789
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.9543 - accuracy: 0.1891
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.7200 - accuracy: 0.1966
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.5420 - accuracy: 0.1906
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.4314 - accuracy: 0.1949
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.3646 - accuracy: 0.1920
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.3153 - accuracy: 0.1926
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2915 - accuracy: 0.1266
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1537 - accuracy: 0.1957
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0820 - accuracy: 0.2149
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0237 - accuracy: 0.2286
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0009 - accuracy: 0.2491
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9752 - accuracy: 0.2594
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9615 - accuracy: 0.2546
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9368 - accuracy: 0.2689
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9242 - accuracy: 0.2626
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9169 - accuracy: 0.2751
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 86811170 nonzeros
# Model fingerprint: 0xe755cd14
# Coefficient statistics:
#   Matrix range     [2e-13, 4e+00]
#   Objective range  [1e-09, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 510 rows and 242 columns (presolve time = 7s) ...
# Presolve removed 510 rows and 242 columns (presolve time = 11s) ...
# Presolve removed 510 rows and 242 columns (presolve time = 27s) ...
# Presolve removed 510 rows and 242 columns (presolve time = 39s) ...
# Presolve removed 510 rows and 242 columns (presolve time = 41s) ...
# Presolve removed 7087 rows and 242 columns
# Presolve time: 42.75s
# Presolved: 6577 rows, 13167 columns, 43334405 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.25s
#
# Barrier statistics:
#  AA' NZ     : 2.163e+07
#  Factor NZ  : 2.163e+07 (roughly 180 MB of memory)
#  Factor Ops : 9.486e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.34568976e+00 -3.92883426e+01  4.30e+02 2.49e-14  1.25e+00    56s
#    1   1.06083524e-01 -8.38098583e+00  3.86e+01 5.77e-14  1.79e-01    61s
#
# Barrier performed 1 iterations in 64.94 seconds (42.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1257   -2.6427488e-01   0.000000e+00   0.000000e+00     72s
#
# Solved in 1257 iterations and 72.14 seconds (46.71 work units)
# Optimal objective -2.642748815e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 93327862 nonzeros
# Model fingerprint: 0x5a3b363d
# Coefficient statistics:
#   Matrix range     [2e-10, 2e-01]
#   Objective range  [2e-08, 8e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 0 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 24s) ...
# Presolve removed 0 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 6832 rows and 0 columns
# Presolve time: 27.39s
# Presolved: 6832 rows, 13664 columns, 46670763 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.25s
#
# Barrier statistics:
#  AA' NZ     : 2.333e+07
#  Factor NZ  : 2.334e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.063e+11 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.82804886e+00 -1.04114728e+02  7.55e+02 1.78e-15  2.93e+00    42s
#    1  -9.29807173e-02 -1.40034330e+01  6.05e+00 6.88e-14  2.63e-01    49s
#    2  -4.65884769e-01 -2.36614531e+00  5.71e-01 9.95e-14  3.57e-02    55s
#    3  -1.03492239e+00 -1.58368416e+00  1.61e-01 1.01e-13  1.03e-02    61s
#    4  -1.23135288e+00 -1.42254478e+00  4.87e-02 1.25e-13  3.59e-03    68s
#    5  -1.30814393e+00 -1.35287314e+00  8.48e-03 1.03e-13  8.39e-04    74s
#    6  -1.32547601e+00 -1.33194957e+00  1.30e-03 1.03e-13  1.21e-04    81s
#    7  -1.32891479e+00 -1.32976795e+00  1.39e-04 1.04e-13  1.60e-05    88s
#    8  -1.32937651e+00 -1.32948264e+00  1.35e-05 1.04e-13  1.99e-06    95s
#    9  -1.32943270e+00 -1.32944137e+00  8.07e-07 1.17e-13  1.63e-07   102s
#   10  -1.32943687e+00 -1.32943767e+00  4.22e-08 1.14e-13  1.49e-08   110s
#   11  -1.32943709e+00 -1.32943712e+00  6.13e-09 1.31e-13  5.63e-10   118s
#   12  -1.32943709e+00 -1.32943709e+00  9.50e-11 1.19e-13  2.69e-12   125s
#
# Barrier solved model in 12 iterations and 125.49 seconds (94.33 work units)
# Optimal objective -1.32943709e+00
#
# Crossover log...
#
#      453 DPushes remaining with DInf 0.0000000e+00               128s
#       48 DPushes remaining with DInf 0.0000000e+00               131s
#        0 DPushes remaining with DInf 0.0000000e+00               132s
#
#        4 PPushes remaining with PInf 0.0000000e+00               132s
#        0 PPushes remaining with PInf 0.0000000e+00               132s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.2127508e-12    132s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      460   -1.3294371e+00   0.000000e+00   0.000000e+00    142s
#
# Solved in 460 iterations and 141.61 seconds (103.17 work units)
# Optimal objective -1.329437092e+00
#  60%|██████    | 3/5 [15:37<10:06, 303.25s/it]
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2904 - accuracy: 0.1074
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2447 - accuracy: 0.1460
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1811 - accuracy: 0.1623
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0884 - accuracy: 0.2034
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0285 - accuracy: 0.2394
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9914 - accuracy: 0.2486
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9680 - accuracy: 0.2566
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9545 - accuracy: 0.2600
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9285 - accuracy: 0.2709
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9197 - accuracy: 0.2640
# Epoch 1/10
# 55/55 [==============================] - 1s 3ms/step - loss: 2.2992 - accuracy: 0.1143
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1940 - accuracy: 0.1689
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1322 - accuracy: 0.2011
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0862 - accuracy: 0.2263
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0649 - accuracy: 0.2231
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0313 - accuracy: 0.2414
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0085 - accuracy: 0.2474
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9964 - accuracy: 0.2586
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9774 - accuracy: 0.2757
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9520 - accuracy: 0.2774
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 91759760 nonzeros
# Model fingerprint: 0x479e10c5
# Coefficient statistics:
#   Matrix range     [3e-13, 9e-01]
#   Objective range  [3e-10, 4e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 114 rows and 0 columns (presolve time = 6s) ...
# Presolve removed 114 rows and 54 columns (presolve time = 12s) ...
# Presolve removed 114 rows and 54 columns (presolve time = 24s) ...
# Presolve removed 114 rows and 54 columns (presolve time = 25s) ...
# Presolve removed 6889 rows and 54 columns
# Presolve time: 29.25s
# Presolved: 6775 rows, 13553 columns, 45873646 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 2.295e+07
#  Factor NZ  : 2.295e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.037e+11 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -4.30979335e+00 -1.72753019e+02  7.68e+02 1.78e-15  2.45e+00    46s
#    1  -2.02854538e-01 -1.67426062e+01  2.96e+01 5.06e-14  1.65e-01    55s
#    2  -4.09183771e-01 -2.28878115e+00  3.88e+00 4.88e-14  1.81e-02    64s
#    3  -9.82248807e-01 -1.34257164e+00  4.59e-01 5.80e-14  3.43e-03    73s
#    4  -1.07032046e+00 -1.24004497e+00  2.00e-01 6.28e-14  1.62e-03    82s
#    5  -1.12621916e+00 -1.18374769e+00  4.69e-02 6.96e-14  5.46e-04    92s
#    6  -1.14156017e+00 -1.15090142e+00  9.17e-03 9.24e-14  8.88e-05   101s
#    7  -1.14587039e+00 -1.14691430e+00  6.38e-04 8.84e-14  9.90e-06   111s
#    8  -1.14631617e+00 -1.14642153e+00  4.38e-05 7.89e-14  9.98e-07   121s
#    9  -1.14636092e+00 -1.14637306e+00  2.87e-06 9.26e-14  1.15e-07   131s
#   10  -1.14636487e+00 -1.14636551e+00  1.85e-07 7.98e-14  6.11e-09   141s
#   11  -1.14636509e+00 -1.14636513e+00  3.15e-08 7.95e-14  3.72e-10   151s
#
# Barrier performed 11 iterations in 150.72 seconds (150.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5464   -1.1463651e+00   0.000000e+00   0.000000e+00    157s
#
# Solved in 5464 iterations and 157.46 seconds (181.66 work units)
# Optimal objective -1.146365103e+00
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 90900632 nonzeros
# Model fingerprint: 0x1d206607
# Coefficient statistics:
#   Matrix range     [9e-13, 1e+00]
#   Objective range  [1e-08, 5e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 176 rows and 0 columns (presolve time = 7s) ...
# Presolve removed 176 rows and 87 columns (presolve time = 12s) ...
# Presolve removed 176 rows and 87 columns (presolve time = 24s) ...
# Presolve removed 176 rows and 87 columns (presolve time = 26s) ...
# Presolve removed 6920 rows and 87 columns
# Presolve time: 29.50s
# Presolved: 6744 rows, 13489 columns, 45456885 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 2.274e+07
#  Factor NZ  : 2.274e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.023e+11 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3
work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3112   -6.6654799e-01   0.000000e+00   0.000000e+00     92s
#
# Solved in 3112 iterations and 91.88 seconds (93.25 work units)
# Optimal objective -6.665479908e-01
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 13664 rows, 6832 columns and 90958030 nonzeros
# Model fingerprint: 0xebe0debe
# Coefficient statistics:
#   Matrix range     [8e-13, 7e-01]
#   Objective range  [9e-08, 4e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 172 rows and 2 columns (presolve time = 7s) ...
# Presolve removed 172 rows and 85 columns (presolve time = 12s) ...
# Presolve removed 172 rows and 85 columns (presolve time = 24s) ...
# Presolve removed 172 rows and 85 columns (presolve time = 25s) ...
# Presolve removed 6918 rows and 85 columns
# Presolve time: 29.24s
# Presolved: 6746 rows, 13493 columns, 45485594 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier statistics:
#  AA' NZ     : 2.275e+07
#  Factor NZ  : 2.276e+07 (roughly 200 MB of memory)
#  Factor Ops : 1.024e+11 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.54964248e+00 -9.11606935e+01  3.33e+02 8.88e-16  1.30e+00    44s
#    1  -2.48001330e-01 -9.10592153e+00  2.30e+01 5.57e-14  9.20e-02    52s
#    2  -7.62032767e-01 -1.73851307e+00  2.50e+00 6.46e-14  9.56e-03    59s
#    3  -1.02681434e+00 -1.37780601e+00  9.39e-01 6.60e-14  3.43e-03    68s
#    4  -1.14555517e+00 -1.28001272e+00  2.80e-01 5.35e-14  1.30e-03    75s
#    5  -1.19072916e+00 -1.22210191e+00  4.62e-02 4.66e-14  3.02e-04    84s
#    6  -1.20206772e+00 -1.20459237e+00  1.69e-03 9.95e-14  2.41e-05    92s
#    7  -1.20294294e+00 -1.20321190e+00  7.57e-05 5.11e-14  2.56e-06   100s
#    8  -1.20302492e+00 -1.20304311e+00  5.22e-06 5.33e-14  1.73e-07   109s
#    9  -1.20303344e+00 -1.20303480e+00  3.20e-07 6.84e-14  1.29e-08   118s
#   10  -1.20303428e+00 -1.20303433e+00  1.05e-07 1.37e-13  4.37e-10   127s
#   11  -1.20303430e+00 -1.20303430e+00  1.01e-08 5.02e-14  8.70e-12   136s
#
# Barrier solved model in 11 iterations and 136.09 seconds (162.88 work units)
# Optimal objective -1.20303430e+00
#
# Crossover log...
#
#      292 DPushes remaining with DInf 0.0000000e+00               138s
#       25 DPushes remaining with DInf 0.0000000e+00               140s
#        0 DPushes remaining with DInf 0.0000000e+00               140s
#
#        7 PPushes remaining with PInf 0.0000000e+00               141s
#        0 PPushes remaining with PInf 0.0000000e+00               141s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.6287413e-12    141s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      302   -1.2030343e+00   0.000000e+00   0.000000e+00    152s
#
# Solved in 302 iterations and 151.89 seconds (168.67 work units)
# Optimal objective -1.203034300e+00
# 100%|██████████| 5/5 [27:38<00:00, 331.79s/it]

# %%
best_individual # [5, 3, 'tanh', 'adam']
# Out:
# [15, 3, 'relu', 1.5260539923722828e-07]

# %%
best_fitness
# Out:
# 1.8272013664245605

# %%
# s = evaluate_model(best_individual)
# s

# %%
population_with_fitness
# Out:
# [[15, 3, 'relu', 1.5260539923722828e-07, 1.8272013664245605],
#  [15, 3, 'tanh', 0.06594886242309055, 1.829402208328247],
#  [15, 3, 'relu', 0.09018558650309791, 1.8299793004989624],
#  [5, 2, 'tanh', 0.0631767487548697, 1.8606630563735962],
#  [5, 3, 'tanh', 7.216560929843531e-08, 1.8620715141296387],
#  [15, 1, 'sigmoid', 8.484527069257649e-08, 1.8675769567489624],
#  [15, 3, 'relu', 0.0903385981646327, 1.8821998834609985],
#  [15, 3, 'relu', 0.07533746453026165, 1.889880657196045],
#  [15, 3, 'relu', 0.07474082851512698, 1.9467943906784058],
#  [5, 3, 'tanh', 1.531303440426374e-07, 1.9556595087051392]]

# %%
best_individual
# Out:
# [15, 3, 'relu', 1.5260539923722828e-07]

# %%
number_of_layers = best_individual[1]
neurons_per_layer = best_individual[0]
activation_function = best_indvidual[2]
reg = best_individual[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-8f3e71b643b4> in <module>
#       1 number_of_layers = best_individual[1]
#       2 neurons_per_layer = best_individual[0]
# ----> 3 activation_function = best_indvidual[2]
#       4 reg = best_individual[3]
#
# NameError: name 'best_indvidual' is not defined

# %%
model = Sequential()
model.add(Dense(units = 2,input_dim = 3072))
for i in range(number_of_layers):
  model.add(Dense(units = neurons_per_layer, activation = activation_function, kernel_regularizer = tf.keras.regularizers.L2(reg)))
model.add(Dense(units = 10,activation = "softmax",kernel_regularizer = tf.keras.regularizers.L2(reg)))
model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),optimizer = "Adam", metrics = ["accuracy"])

# %%
model.fit(x_train,y_training, epochs = 10, batch_size = 64)
_,accuracy = model.evaluate(x_eval,y_val_array)
# Out:
# Epoch 1/10
# 55/55 [==============================] - 3s 3ms/step - loss: 2.2970 - accuracy: 0.1106
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2625 - accuracy: 0.1411
# Epoch 3/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.2150 - accuracy: 0.1471
# Epoch 4/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1653 - accuracy: 0.1597
# Epoch 5/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1281 - accuracy: 0.1746
# Epoch 6/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0778 - accuracy: 0.1840
# Epoch 7/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0545 - accuracy: 0.2157
# Epoch 8/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0308 - accuracy: 0.2306
# Epoch 9/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0329 - accuracy: 0.2411
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0120 - accuracy: 0.2409
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0687 - accuracy: 0.2220

# %%
accuracy##accuracy of model with LP
# Out:
# 0.22200000286102295

# %%
import pickle

# %%
file_to_store_loss  = open("GA_CIFAR_WITH_LP","wb")
pickel.dump(file_to_store_loss,generation_wise_best_loss)
file_to_store_loss.close()

# %%
population_with_fitness[0]

# %%
number_of_layers = 3
neurons_per_layer = 10
activation_function = "relu"
reg = 1.5260539923722828e-07

# %%
y_pred_test = model(x_test,training = False)

# %%
loss_object(y_pred_test,y_testing).numpy()
# Out:
# 13.696813470037549
