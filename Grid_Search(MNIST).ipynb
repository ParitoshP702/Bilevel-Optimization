# %% [markdown]
# <a href="https://colab.research.google.com/github/ParitoshP702/Bilevel-Optimization/blob/main/Grid_Search(MNIST).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd

# %%
(X_train,Y_train),(X_test,Y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
pip install gurobipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gurobipy
#   Downloading gurobipy-10.0.0-cp38-cp38-manylinux2014_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 8.5 MB/s
# Installing collected packages: gurobipy
# Successfully installed gurobipy-10.0.0

# %%
import gurobipy as gp

# %%
 params = {
  "WLSACCESSID": '753e7886-7142-449d-8baa-d41ca78716ef',
  "WLSSECRET": '880d2525-364b-41d0-ac23-6dcf7ad15312',
  "LICENSEID": 914249,
  }
env = gp.Env(params=params)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 914249
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in

# %%
train_count = 5000
test_count = 2500
eval_count = 2500

# %%
x_train = X_train[:train_count,:,:]
y_train = Y_train[:train_count]
x_eval = X_train[train_count:train_count+eval_count,:,:]
y_eval = Y_train[train_count:train_count+eval_count]
x_test = X_test[:test_count,:,:]
y_test = Y_test[:test_count]

# %%
x_train = x_train.reshape(x_train.shape[0],-1)
x_eval = x_eval.reshape(x_eval.shape[0],-1)
x_test = x_test.reshape(x_test.shape[0],-1)

# %%
y_training = np.zeros(shape = (len(y_train),10),dtype = float)
for i in range(len(y_train)):
  for j in range(10):
    if j == y_train[i]:
      y_training[i][j] = 1.0
    else:
      y_training[i][j] = 0.0

# %%
y_val_array = np.zeros(shape = (len(y_eval),10),dtype= float)
for i in range(len(y_eval)):
  for j in range(10):
    if j == y_eval[i]:
      y_val_array[i][j] = 1.0
    else:
      y_val_array[i][j] = 0.0

# %%
x_train = x_train/255.0
x_eval = x_eval/255.0
x_test = x_test/255.0

# %%
y_testing = np.zeros(shape = (len(y_test),10),dtype = float)
for i in range(len(y_test)):
  for j in range(10):
    if j == y_test[i]:
      y_testing[i][j] = 1.0
    else:
      y_testing[i][j] = 0.0

# %%
loss_object = tf.keras.losses.CategoricalCrossentropy()

# %%
# def build_model(number_of_layers,neurons_per_layer,activation_function,regularization_param):
#   model = Sequential()
#   model.add(Dense(units = 6,input_dim = 784))
#   # neurons_per_layer = hp.Choice("neurons_per_layer",[5,10,15])
#   for i in range(number_of_layers):
#     model.add(Dense(units = neurons_per_layer,activation = activation_function,kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))
#   model.add(Dense(units = 10,activation = "softmax",kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))
#   model.compile(loss = "categorical_crossentropy",optimizer = "Adam",metrics = ["accuracy"])
#   model.fit(x_train,y_training,epochs = 10,batch_size = 64)
#   y_pred_array = model(x_eval,training = False)
#   loss = loss_object(y_pred_array,y_val_array)
#   return loss,model

# %%
# x_train[0]

# %%
def complete_weight_array(model):
  weights_list = []
  for i in range(len(model.weights)):
    weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
    if i%2 == 0:
      shape_array = weights_array.shape
      for j in range(shape_array[0]):
        for k in range(shape_array[1]):
          weights_list.append(weights_array[j][k])
          # if len(weights_list_new) < skip_length:
          #   weights_list_new.append(0)
          # else:
          #   weights_list_new.append(weights_array[j][k])
    else:
      lgt = weights_array.shape[0]
      for j in range(lgt):
        weights_list.append(weights_array[j])
        # if len(weights_list_new) < skip_length:
        #   weights_list_new.append(0)
        # else:
        #   weights_list_new.append(weights_array[j])
  return np.array(weights_list)

# %%
def weight_array_for_hessian(model):
  skip_length = len(model.layers[0].weights[0].numpy().reshape(-1)) + len(model.layers[0].weights[1].numpy().reshape(-1))
  weights_list = []
  for i in range(len(model.weights)):
    weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
    if i%2 == 0:
      shape_array = weights_array.shape
      for j in range(shape_array[0]):
        for k in range(shape_array[1]):
          # weights_list.append(weights_array[j][k])
          if len(weights_list) < skip_length:
            weights_list.append(0)
          else:
            weights_list.append(weights_array[j][k])
    else:
      lgt = weights_array.shape[0]
      for j in range(lgt):
        # weights_list.append(weights_array[j])
        if len(weights_list) < skip_length:
          weights_list.append(0)
        else:
          weights_list.append(weights_array[j])
  return np.array(weights_list)

# %%
def compute_gradient(x_target,y_target,model):##general function which returns the list of gradient vector as an numpy array
  with tf.GradientTape() as tape:
    loss_object = tf.keras.losses.MeanSquaredError()
    y_pred_array = model(x_target,training = True)
    loss = loss_object(y_target,y_pred_array)
  g = tape.gradient(loss,model.trainable_variables)
  final_grad_list = []
  for i in range(len(g)):
    grad_array = tf.make_ndarray(tf.make_tensor_proto(g[i]))
    if i%2==0:
      grad_shape = grad_array.shape
      for j in range(grad_shape[0]):
        for k in range(grad_shape[1]):
          final_grad_list.append(grad_array[j][k])
    else:
      length = grad_array.shape[0]
      for j in range(length):
        final_grad_list.append(grad_array[j])
  return np.array(final_grad_list)

# %%
def compute_hessian(model):
  final_hessian_list = []
  with tf.GradientTape(persistent = True) as tape1:
    with tf.GradientTape(persistent = True) as tape2:
      loss_object = tf.keras.losses.CategoricalCrossentropy()
      y_pred_array = model(x_train,training = True)
      loss = loss_object(y_training,y_pred_array)
    g = tape2.gradient(loss, model.trainable_variables)
  for i in range(len(g)):
    # reshaped_grad = tf.reshape(g[i], [-1])
    h = tape1.jacobian(g[i],model.trainable_variables)
    final_hessian_list.append(h)


  ##Now this final hessian list is actually a double dimensional list of tensors, so we will convert it into a matrix
  #reshaping the double dimensional list of tensors into a matrix
  hessian_matrix = np.empty(shape = (1,1),dtype = float)
  for i in range(len(final_hessian_list)):
    hess_col_mat = np.empty(shape = (1,1),dtype = float)
    for j in range(len(final_hessian_list[i])):
      hess_array = tf.make_ndarray(tf.make_tensor_proto(final_hessian_list[i][j]))
      hess_shape = hess_array.shape
      if i%2 == 0:
        if j%2 == 0:
          hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2]*hess_shape[3])
        else:
          hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2])
      else:
        if j%2 == 0:
          hess_array = hess_array.reshape(hess_shape[0],hess_shape[1]*hess_shape[2])
        else:
          hess_array = hess_array
      if j==0 :
        hess_col_mat = hess_array
      else:
        hess_col_mat = np.concatenate((hess_col_mat,hess_array),axis = 1)
    if i==0:
      hessian_matrix = hess_col_mat
    else:
      hessian_matrix= np.concatenate((hessian_matrix,hess_col_mat),axis = 0)


  return hessian_matrix

# %%
def perform_fine_tuning(model,params_model):
  number_of_layers = params_model[1]
  reg_param = params_model[3]
  neurons_per_layer = params_model[0]
  activation_fun = params_model[2]

  ###calculating the hessian for the model and the gradient of the validation loss
  hessian_matrix = compute_hessian(model)
  grad_validation = compute_gradient(x_eval,y_val_array,model)
  final_weights_array_new = weight_array_for_hessian(model)
  l = len(final_weights_array_new)


  ##adding the regularization term in the hessian
  weight_array_vec = final_weights_array_new.reshape(l,1)/len(y_train)
  hessian_col_mat = np.concatenate((weight_array_vec,hessian_matrix),axis = 1)
  weight_array_withreg = np.concatenate(([[0]],final_weights_array_new.reshape(1,l)),axis = 1)/len(y_train)
  hessian_mat_with_reg = np.concatenate((weight_array_withreg,hessian_col_mat),axis = 0)


  grad_validation_new = np.concatenate(([[0]],grad_validation.reshape(1,l)),axis = 1)#validation array with regularization


  ##Solving the linear program
  ub = [10 for i in range(l+1)]
  lb = []
  for i in range(l+1):
    if i==0:
      lb.append(1e-5)
    else:
      lb.append(-10)


  # Create the model within the Gurobi environment
  m = gp.Model(env=env)
  # m = gp.Model()
  x = m.addMVar((l+1,),lb = lb, ub = ub )
  m.setObjective(grad_validation_new@x)
  # m.addConstr(hessian_mat_with_reg@x == 0)
  m.addConstr(hessian_mat_with_reg@x <= 0.1)
  m.addConstr(hessian_mat_with_reg@x >= -0.1)
  x.PStart = np.zeros(l+1)
  # GRBModel.Set(Pstart = np.zeros(l+1))
  m.optimize()
  all_vars = m.getVars()
  values = m.getAttr("x",all_vars)
  values = np.array(values)
  values = values/np.linalg.norm(values)

  final_weights_array = complete_weight_array(model)
  weight_array_with_reg = np.concatenate(([[reg_param]],final_weights_array.reshape(1,l)),axis = 1).reshape(-1)
  descent_factors = []
  for i in range(-100,20000,200):
    descent_factors.append(i*1e-3)
  descent_factors = np.array(descent_factors)


  weight_sample_space_matrix = np.empty(shape = (len(descent_factors),len(weight_array_with_reg)),dtype = float)##initializing the weight sample space matrix
  for i in range(len(descent_factors)):
    weight_sample_space_matrix[i] =weight_array_with_reg+ values*descent_factors[i]   ##assigning values to the weight sample space matrix


  ##defining the loss object
  loss_object = tf.keras.losses.CategoricalCrossentropy()

  ##computation for validation loss
  def validation_loss_computation(weight_and_reg_array):##function which computes the loss score of the model corresponding to given weights

      model_demo = Sequential()
      model_demo.add(Dense(units = 6, input_dim = 784))
      for i in range(number_of_layers):
          model_demo.add(Dense(units = neurons_per_layer, activation = activation_fun, kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
      model_demo.add(Dense(units = 10,activation = "softmax", kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
      model_demo.compile(loss = "mean_squared_error", optimizer = "Adam", metrics = ["accuracy"])
      weight_tracker = 1##as "weight_and_reg_array" is a one dimensional array it keeps track of the indices of the array
      for i in range(len(model_demo.layers)):##changing the weights of the model layer wise
        orignal_weight_list = model.layers[i].weights
        array_1 = orignal_weight_list[0].numpy()##array corresponding to the weight matrix
        array_2 = orignal_weight_list[1].numpy()##array corresponding to the bias vector
        array_1_new = weight_and_reg_array[weight_tracker:weight_tracker+array_1.shape[0]*array_1.shape[1]]
        weight_tracker += array_1.shape[0]*array_1.shape[1]##updating the weight tracker
        array_2_new = weight_and_reg_array[weight_tracker:weight_tracker + array_2.shape[0]]
        weight_tracker += array_2.shape[0] #updating the weight tracker
        array_1_new = array_1_new.reshape(array_1.shape) ##new weight matrix
        array_2_new = array_2_new.reshape(array_2.shape) ##new bias vector
        list_of_new_array = [] ##list of the new weight matrix and the new bias vector
        list_of_new_array.append(array_1_new)
        list_of_new_array.append(array_2_new)
        model_demo.layers[i].set_weights(list_of_new_array) ##appending the new weights into the given layer of the model
      y_pred_array = model_demo(np.array(x_eval),training = False)
      y_pred_training = model_demo(np.array(x_train),training = False)
      loss = loss_object(y_val_array,y_pred_array)
      loss_t = loss_object(y_training,y_pred_training)
      # loss1,_ = model_demo.evaluate(x_eval,y_eval,verbose= 0)
      # loss2,_= model_demo.evaluate(x_train,y_train,verbose = 0)
      return loss,loss_t,model_demo


  loss_array_valid = np.empty(shape = len(descent_factors),dtype = float)##array to contain the training losses
  loss_array_train = np.empty(shape = len(descent_factors),dtype = float)##array to contain the validation losses

  for i in range(len(loss_array_valid)):
    loss_array_valid[i] ,loss_array_train[i],_= validation_loss_computation(weight_sample_space_matrix[i])


  ideal_weight_array = weight_sample_space_matrix[loss_array_valid.argmin()]
  ideal_regularization_parameter = ideal_weight_array[0]
  _,_,best_model = validation_loss_computation(ideal_weight_array)

  return ideal_weight_array[0],best_model,loss_array_valid.min()

# %%
# def hyperparameters(returnAs='vals'):
#     parameters = {}

#     #Add other parameters here

#     parameters["neurons_per_layer"] = [5,10,15]
#     parameters["number_of_layers"] = [1, 2, 3]
#     parameters["activation_function"] = ['relu', 'tanh', 'sigmoid']
#     parameters["regularization_parameter"] = [1e-10,1e-9,1e-8]
#     #Search over regularization parameter as well
#     #parameters["regularization"] = []

#     #Keep the last one as optimizer
#     #parameters["optimization_method"] = ['adam', 'rmsprop']
#     # parameters["optimization_method"] = ['adam']

#     if returnAs == 'dict': return(parameters)
#     if returnAs == 'vals': return(list(parameters.values()))
#     if returnAs == 'keys': return(list(parameters.keys()))

# # def hyperparameters_old():
# #     parameters = []
# #     units_per_layer = [5, 10, 15]
# #     layers = [1, 2, 3]
# #     activation = ['relu', 'tanh', 'sigmoid']
# #     optimizer = ['adam', 'rmsprop']
# #     parameters.append(units_per_layer)
# #     parameters.append(layers)
# #     parameters.append(activation)
# #     parameters.append(optimizer)

# #     return(parameters)

# %%
def generate_population():
  neurons_per_layer = [5,10,15]
  number_of_layers = [1,2,3]
  activation_function = ["relu","sigmoid","tanh"]
  regularization_param = [1e-10,1e-9,1e-8]
  param_dict = []
  for i in range(len(neurons_per_layer)):
    for j in range(len(number_of_layers)):
      for k in range(len(activation_function)):
        for l in range(len(regularization_param)):
          dic = [neurons_per_layer[i],number_of_layers[j],activation_function[k],regularization_param[l]]
          param_dict.append(dic)
   return param_dict

# %%
# neurons_per_layer = [5,10,15]
# number_of_layers = [1,2,3]
# activation_function = ["relu","sigmoid","tanh"]
# regularization_param = [1e-10,1e-9,1e-8]

# %%
# loss_array = []
# model_array = []
# param_dict = []
# for i in range(len(neurons_per_layer)):
#   for j in range(len(number_of_layers)):
#     for k in range(len(activation_function)):
#       for l in range(len(regularization_param)):
#         dic = [neurons_per_layer[i],number_of_layers[j],activation_function[k],regularization_param[l]]
#         param_dict.append(dic)
#         loss,model  = build_model(number_of_layers[j],neurons_per_layer[i],activation_function[k],regularization_param[l])
#         loss_array.append(loss)
#         model_array.append(model)
# Out:
# Epoch 1/10
# 79/79 [==============================] - 4s 2ms/step - loss: 2.0298 - accuracy: 0.2670
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.7333 - accuracy: 0.4226
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.5585 - accuracy: 0.4702
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.4276 - accuracy: 0.5124
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.3197 - accuracy: 0.5452
# Epoch 6/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2140 - accuracy: 0.5742
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.0993 - accuracy: 0.6130
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.9922 - accuracy: 0.6726
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8764 - accuracy: 0.7228
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7555 - accuracy: 0.7652
# Epoch 1/10
# 79/79 [==============================] - 1s 2ms/step - loss: 2.0371 - accuracy: 0.2520
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6191 - accuracy: 0.5146
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.2701 - accuracy: 0.6192
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.9841 - accuracy: 0.7120
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7974 - accuracy: 0.7746
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.8072
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6233 - accuracy: 0.8238
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.8384
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.8526
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.8570
# Epoch 1/10
# 79/79 [==============================] - 1s 2ms/step - loss: 1.9866 - accuracy: 0.2660
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6539 - accuracy: 0.3986
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.4179 - accuracy: 0.4790
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.1924 - accuracy: 0.6006
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.9544 - accuracy: 0.7070
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.8326 - accuracy: 0.7414
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7685 - accuracy: 0.7628
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.7280 - accuracy: 0.7764
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6967 - accuracy: 0.7852
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 0.6722 - accuracy: 0.7928
# Epoch 1/10
# 79/79 [==============================] - 1s 2ms/step - loss: 2.1748 - accuracy: 0.1474
# Epoch 2/10
# 79/79 [==============================] - 0s 3ms/step - loss: 2.0018 - accuracy: 0.2952
# Epoch 3/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.8981 - accuracy: 0.3786
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.8069 - accuracy: 0.4438
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.7232 - accuracy: 0.5288
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6428 - accuracy: 0.5512
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.5667 - accuracy: 0.5698
# Epoch 8/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4978 - accuracy: 0.5856
# Epoch 9/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4375 - accuracy: 0.5998
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.3835 - accuracy: 0.6088
# Epoch 1/10
# 79/79 [==============================] - 1s 2ms/step - loss: 2.2384 - accuracy: 0.1726
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 2.0540 - accuracy: 0.3248
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.9404 - accuracy: 0.3626
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.8427 - accuracy: 0.4350
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.7547 - accuracy: 0.5066
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6742 - accuracy: 0.5866
# Epoch 7/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6006 - accuracy: 0.6094
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.5339 - accuracy: 0.6228
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.4733 - accuracy: 0.6364
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.4173 - accuracy: 0.6480
# Epoch 1/10
# 79/79 [==============================] - 1s 3ms/step - loss: 2.2246 - accuracy: 0.2094
# Epoch 2/10
# 79/79 [==============================] - 0s 2ms/step - loss: 2.0334 - accuracy: 0.4116
# Epoch 3/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.8803 - accuracy: 0.5794
# Epoch 4/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.7553 - accuracy: 0.6188
# Epoch 5/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.6501 - accuracy: 0.6474
# Epoch 6/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.5600 - accuracy: 0.6610
# Epoch 7/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.4796 - accuracy: 0.6786
# Epoch 8/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.4086 - accuracy: 0.6958
# Epoch 9/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.3435 - accuracy: 0.7092
# Epoch 10/10
# 79/79 [==============================] - 0s 2ms/step - loss: 1.2833 - accuracy: 0.7240
# Epoch 1/10
# 79/79 [==============================] - 1s 2ms/step - loss: 1
# Epoch 4/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7821 - accuracy: 0.8100
# Epoch 5/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.6556 - accuracy: 0.8390
# Epoch 6/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.8578
# Epoch 7/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.8704
# Epoch 8/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.8856
# Epoch 9/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.4187 - accuracy: 0.8914
# Epoch 10/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3862 - accuracy: 0.9004
# Epoch 1/10
# 79/79 [==============================] - 1s 3ms/step - loss: 1.8102 - accuracy: 0.4052
# Epoch 2/10
# 79/79 [==============================] - 0s 3ms/step - loss: 1.2340 - accuracy: 0.6774
# Epoch 3/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.9190 - accuracy: 0.8006
# Epoch 4/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.7064 - accuracy: 0.8406
# Epoch 5/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.8724
# Epoch 6/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.4908 - accuracy: 0.8830
# Epoch 7/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.4329 - accuracy: 0.8916
# Epoch 8/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3947 - accuracy: 0.8986
# Epoch 9/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.9056
# Epoch 10/10
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.9136

# %%
def train_model(parameters,initialWeights=None):
    neurons_per_layer = parameters[0]
    no_of_layers = parameters[1]
    activation_function = parameters[2]

    #Following is not used here
    # optimization_method = parameters[3]
    regularization_param = parameters[3]

    model = Sequential()
    model.add(Dense(units=6, input_dim=784))

    for _ in range(no_of_layers):
        model.add(Dense(units=neurons_per_layer, activation=activation_function,kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))

    model.add(Dense(units = 10,  activation = 'softmax',kernel_regularizer = tf.keras.regularizers.L2(regularization_param)))




    return(model)

def evaluate_model(individual,initialWeights=None):
    model = train_model(individual,initialWeights)

    #The last element in the individual should always be the optimizer
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer="Adam", metrics=['accuracy'])
    model.fit(x_train, y_training, batch_size = 64, epochs = 10)

    # print("Training Accuracy:", model.evaluate(x_train, y_train, verbose = 0)[1])

    #Evaluate on evaluation data
    # loss_score, accuracy_score = model.evaluate(x_eval, y_val_array, verbose = 0)
    y_pred = model(x_eval,training = False)
    loss_score = loss_object(y_pred,y_val_array)
    return loss_score,model

# %%
initial_population = generate_population()
losses = []
models = []
# losses = [evaluate_model(individual) for individual in initial_population]
for individual in initial_population:
  loss,model = evaluate_model(individual)
  losses.append(loss)
  models.append(model)
losses_new = np.zeros(len(losses))
models_new = [None]*(len(models))
for i in range(len(models)):
  initial_population[i][3],models_new[i],losses_new[i] = perform_fine_tuning(models[i],initial_population[i])

# %%
# np.array(loss_array).min()
# Out:
# 3.251642154809741

# %%
np.array(losses).min()

# %%
losses_new.min()

# %%
best_param = initial_population[np.array(losses).argmin()]

# %%
reg = best_param[3]
number_of_layers=  best_param[0]
neuron_per_layer = best_param[1]
activation_function = best_param[2]

# %%
model = Sequential()
model.add(Dense(units = 6,input_dim = 784 ))
for i in range(number_of_layers):
  model.add(Dense(units = neuron_per_layer, activation = activation_function, kernel_regularizer = tf.keras.regularizers.L2(reg)))
model.add(Dense(units = 10,activation = "softmax", kernel_regularizer = tf.keras.regularizers.L2(reg) ))

# %%
model.compile(loss = tf.keras.losses.CategoricalCrossentropy(), optimizer = "Adam", metrics = ["accuracy"])
model.fit(x_train,y_training, epochs = 10,batch_size = 64)
y_pred = model(x_eval,training = False)
loss_object(y_pred,y_val_array)

# %% [markdown]
# #Finetuning every model in our Grid Search Code

# %%
# def complete_weight_array(model):
#   weights_list = []
#   for i in range(len(model.weights)):
#     weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
#     if i%2 == 0:
#       shape_array = weights_array.shape
#       for j in range(shape_array[0]):
#         for k in range(shape_array[1]):
#           weights_list.append(weights_array[j][k])
#           # if len(weights_list_new) < skip_length:
#           #   weights_list_new.append(0)
#           # else:
#           #   weights_list_new.append(weights_array[j][k])
#     else:
#       lgt = weights_array.shape[0]
#       for j in range(lgt):
#         weights_list.append(weights_array[j])
#         # if len(weights_list_new) < skip_length:
#         #   weights_list_new.append(0)
#         # else:
#         #   weights_list_new.append(weights_array[j])
#   return np.array(weights_list)

# %%
# def weight_array_for_hessian(model):
#   skip_length = len(model.layers[0].weights[0].numpy().reshape(-1)) + len(model.layers[0].weights[1].numpy().reshape(-1))
#   weights_list = []
#   for i in range(len(model.weights)):
#     weights_array = tf.make_ndarray(tf.make_tensor_proto(model.weights[i]))
#     if i%2 == 0:
#       shape_array = weights_array.shape
#       for j in range(shape_array[0]):
#         for k in range(shape_array[1]):
#           # weights_list.append(weights_array[j][k])
#           if len(weights_list) < skip_length:
#             weights_list.append(0)
#           else:
#             weights_list.append(weights_array[j][k])
#     else:
#       lgt = weights_array.shape[0]
#       for j in range(lgt):
#         # weights_list.append(weights_array[j])
#         if len(weights_list) < skip_length:
#           weights_list.append(0)
#         else:
#           weights_list.append(weights_array[j])
#   return np.array(weights_list)

# %%
# def compute_gradient(x_target,y_target,model):##general function which returns the list of gradient vector as an numpy array
#   with tf.GradientTape() as tape:
#     loss_object = tf.keras.losses.MeanSquaredError()
#     y_pred_array = model(x_target,training = True)
#     loss = loss_object(y_target,y_pred_array)
#   g = tape.gradient(loss,model.trainable_variables)
#   final_grad_list = []
#   for i in range(len(g)):
#     grad_array = tf.make_ndarray(tf.make_tensor_proto(g[i]))
#     if i%2==0:
#       grad_shape = grad_array.shape
#       for j in range(grad_shape[0]):
#         for k in range(grad_shape[1]):
#           final_grad_list.append(grad_array[j][k])
#     else:
#       length = grad_array.shape[0]
#       for j in range(length):
#         final_grad_list.append(grad_array[j])
#   return np.array(final_grad_list)

# %%
# def compute_hessian(model):
#   final_hessian_list = []
#   with tf.GradientTape(persistent = True) as tape1:
#     with tf.GradientTape(persistent = True) as tape2:
#       loss_object = tf.keras.losses.CategoricalCrossentropy()
#       y_pred_array = model(x_train,training = True)
#       loss = loss_object(y_training,y_pred_array)
#     g = tape2.gradient(loss, model.trainable_variables)
#   for i in range(len(g)):
#     # reshaped_grad = tf.reshape(g[i], [-1])
#     h = tape1.jacobian(g[i],model.trainable_variables)
#     final_hessian_list.append(h)


#   ##Now this final hessian list is actually a double dimensional list of tensors, so we will convert it into a matrix
#   #reshaping the double dimensional list of tensors into a matrix
#   hessian_matrix = np.empty(shape = (1,1),dtype = float)
#   for i in range(len(final_hessian_list)):
#     hess_col_mat = np.empty(shape = (1,1),dtype = float)
#     for j in range(len(final_hessian_list[i])):
#       hess_array = tf.make_ndarray(tf.make_tensor_proto(final_hessian_list[i][j]))
#       hess_shape = hess_array.shape
#       if i%2 == 0:
#         if j%2 == 0:
#           hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2]*hess_shape[3])
#         else:
#           hess_array = hess_array.reshape(hess_shape[0]*hess_shape[1],hess_shape[2])
#       else:
#         if j%2 == 0:
#           hess_array = hess_array.reshape(hess_shape[0],hess_shape[1]*hess_shape[2])
#         else:
#           hess_array = hess_array
#       if j==0 :
#         hess_col_mat = hess_array
#       else:
#         hess_col_mat = np.concatenate((hess_col_mat,hess_array),axis = 1)
#     if i==0:
#       hessian_matrix = hess_col_mat
#     else:
#       hessian_matrix= np.concatenate((hessian_matrix,hess_col_mat),axis = 0)


#   return hessian_matrix

# %%
# def perform_fine_tuning(model,params_model):
#   number_of_layers = params_model[1]
#   reg_param = params_model[3]
#   neurons_per_layer = params_model[0]
#   activation_fun = params_model[2]

#   ###calculating the hessian for the model and the gradient of the validation loss
#   hessian_matrix = compute_hessian(model)
#   grad_validation = compute_gradient(x_eval,y_val_array,model)
#   final_weights_array_new = weight_array_for_hessian(model)
#   l = len(final_weights_array_new)


#   ##adding the regularization term in the hessian
#   weight_array_vec = final_weights_array_new.reshape(l,1)/len(y_train)
#   hessian_col_mat = np.concatenate((weight_array_vec,hessian_matrix),axis = 1)
#   weight_array_withreg = np.concatenate(([[0]],final_weights_array_new.reshape(1,l)),axis = 1)/len(y_train)
#   hessian_mat_with_reg = np.concatenate((weight_array_withreg,hessian_col_mat),axis = 0)


#   grad_validation_new = np.concatenate(([[0]],grad_validation.reshape(1,l)),axis = 1)#validation array with regularization


#   ##Solving the linear program
#   ub = [10 for i in range(l+1)]
#   lb = []
#   for i in range(l+1):
#     if i==0:
#       lb.append(1e-5)
#     else:
#       lb.append(-10)


#   # Create the model within the Gurobi environment
#   m = gp.Model(env=env)
#   # m = gp.Model()
#   x = m.addMVar((l+1,),lb = lb, ub = ub )
#   m.setObjective(grad_validation_new@x)
#   # m.addConstr(hessian_mat_with_reg@x == 0)
#   m.addConstr(hessian_mat_with_reg@x <= 0.1)
#   m.addConstr(hessian_mat_with_reg@x >= -0.1)
#   x.PStart = np.zeros(l+1)
#   # GRBModel.Set(Pstart = np.zeros(l+1))
#   m.optimize()
#   all_vars = m.getVars()
#   values = m.getAttr("x",all_vars)
#   values = np.array(values)
#   values = values/np.linalg.norm(values)

#   final_weights_array = complete_weight_array(model)
#   weight_array_with_reg = np.concatenate(([[reg_param]],final_weights_array.reshape(1,l)),axis = 1).reshape(-1)
#   descent_factors = []
#   for i in range(-100,20000,200):
#     descent_factors.append(i*1e-3)
#   descent_factors = np.array(descent_factors)


#   weight_sample_space_matrix = np.empty(shape = (len(descent_factors),len(weight_array_with_reg)),dtype = float)##initializing the weight sample space matrix
#   for i in range(len(descent_factors)):
#     weight_sample_space_matrix[i] =weight_array_with_reg+ values*descent_factors[i]   ##assigning values to the weight sample space matrix


#   ##defining the loss object
#   loss_object = tf.keras.losses.CategoricalCrossentropy()

#   ##computation for validation loss
#   def validation_loss_computation(weight_and_reg_array):##function which computes the loss score of the model corresponding to given weights

#       model_demo = Sequential()
#       model_demo.add(Dense(units = 6, input_dim = 784))
#       for i in range(number_of_layers):
#           model_demo.add(Dense(units = neurons_per_layer, activation = activation_fun, kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
#       model_demo.add(Dense(units = 10,activation = "softmax", kernel_regularizer = tf.keras.regularizers.L2(weight_and_reg_array[0])))
#       model_demo.compile(loss = "mean_squared_error", optimizer = "Adam", metrics = ["accuracy"])
#       weight_tracker = 1##as "weight_and_reg_array" is a one dimensional array it keeps track of the indices of the array
#       for i in range(len(model_demo.layers)):##changing the weights of the model layer wise
#         orignal_weight_list = model.layers[i].weights
#         array_1 = orignal_weight_list[0].numpy()##array corresponding to the weight matrix
#         array_2 = orignal_weight_list[1].numpy()##array corresponding to the bias vector
#         array_1_new = weight_and_reg_array[weight_tracker:weight_tracker+array_1.shape[0]*array_1.shape[1]]
#         weight_tracker += array_1.shape[0]*array_1.shape[1]##updating the weight tracker
#         array_2_new = weight_and_reg_array[weight_tracker:weight_tracker + array_2.shape[0]]
#         weight_tracker += array_2.shape[0] #updating the weight tracker
#         array_1_new = array_1_new.reshape(array_1.shape) ##new weight matrix
#         array_2_new = array_2_new.reshape(array_2.shape) ##new bias vector
#         list_of_new_array = [] ##list of the new weight matrix and the new bias vector
#         list_of_new_array.append(array_1_new)
#         list_of_new_array.append(array_2_new)
#         model_demo.layers[i].set_weights(list_of_new_array) ##appending the new weights into the given layer of the model
#       y_pred_array = model_demo(np.array(x_eval),training = False)
#       y_pred_training = model_demo(np.array(x_train),training = False)
#       loss = loss_object(y_val_array,y_pred_array)
#       loss_t = loss_object(y_training,y_pred_training)
#       # loss1,_ = model_demo.evaluate(x_eval,y_eval,verbose= 0)
#       # loss2,_= model_demo.evaluate(x_train,y_train,verbose = 0)
#       return loss,loss_t,model_demo


#   loss_array_valid = np.empty(shape = len(descent_factors),dtype = float)##array to contain the training losses
#   loss_array_train = np.empty(shape = len(descent_factors),dtype = float)##array to contain the validation losses

#   for i in range(len(loss_array_valid)):
#     loss_array_valid[i] ,loss_array_train[i],_= validation_loss_computation(weight_sample_space_matrix[i])


#   ideal_weight_array = weight_sample_space_matrix[loss_array_valid.argmin()]
#   ideal_regularization_parameter = ideal_weight_array[0]
#   _,_,best_model = validation_loss_computation(ideal_weight_array)

#   return ideal_weight_array[0],best_model,loss_array_valid.min()

# %%
# fine_tuned_models = []
# improved_loss = []
# ideal_reg_array = []
# for i in range(len(loss_array)):
#   reg,model,loss = perform_fine_tuning(model_array[i],param_dict[i])
#   improved_loss.append(loss)
#   fine_tuned_models.append(model)
#   ideal_reg_array.append(reg)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f6ab542e0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f6ab542e310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25043458 nonzeros
# Model fingerprint: 0x3678b833
# Coefficient statistics:
#   Matrix range     [1e-13, 2e+00]
#   Objective range  [2e-12, 5e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2354 rows and 757 columns (presolve time = 6s) ...
# Presolve removed 5983 rows and 757 columns
# Presolve time: 8.72s
# Presolved: 3629 rows, 7678 columns, 11848523 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 6.583e+06
#  Factor NZ  : 6.587e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.594e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.06982401e-01 -8.09052137e+03  1.04e+02 1.42e-14  2.53e+01    18s
#    1  -1.25486840e-02 -5.64185742e+02  1.75e+00 7.11e-14  1.22e+00    25s
#    2  -2.76848057e-02 -1.35599027e+01  2.04e-03 4.26e-14  2.82e-02    32s
#    3  -6.85358057e-01 -1.76991404e+00  1.90e-05 5.68e-14  2.26e-03    39s
#    4  -1.25251610e+00 -1.40721143e+00  1.15e-06 8.53e-14  3.22e-04    46s
#    5  -1.32284760e+00 -1.33820687e+00  1.86e-08 2.22e-14  3.20e-05    53s
#    6  -1.32704546e+00 -1.33227515e+00  5.79e-09 1.42e-14  1.09e-05    60s
#    7  -1.32839511e+00 -1.33066244e+00  2.27e-09 1.01e-14  4.72e-06    67s
#    8  -1.32921903e+00 -1.32950953e+00  3.46e-10 1.07e-14  6.05e-07    74s
#    9  -1.32929025e+00 -1.32937344e+00  8.33e-10 2.84e-14  1.73e-07    81s
#
# Barrier performed 9 iterations in 83.76 seconds (193.00 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6451   -1.3293193e+00   0.000000e+00   6.500327e-04     86s
# Extra simplex iterations after uncrush: 7
#     6458   -1.3293447e+00   0.000000e+00   0.000000e+00     86s
#
# Solved in 6458 iterations and 86.18 seconds (104.66 work units)
# Optimal objective -1.329344658e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25067206 nonzeros
# Model fingerprint: 0x2a582ea9
# Coefficient statistics:
#   Matrix range     [1e-13, 5e+00]
#   Objective range  [1e-12, 6e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2482 rows and 760 columns (presolve time = 6s) ...
# Presolve removed 6047 rows and 760 columns
# Presolve time: 8.74s
# Presolved: 3565 rows, 7611 columns, 11736571 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 6.353e+06
#  Factor NZ  : 6.356e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.511e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.85601822e+00 -3.61920599e+03  1.39e+02 7.11e-15  2.28e+01    17s
#    1  -7.32536139e-02 -2.17402536e+02  3.88e+00 4.97e-14  9.75e-01    24s
#    2  -1.05685238e-01 -7.28384831e+00  5.21e-03 4.26e-14  3.02e-02    31s
#    3  -9.62366860e-01 -1.74096033e+00  2.50e-04 5.68e-14  3.27e-03    38s
#    4  -1.28709267e+00 -1.37276235e+00  8.58e-06 4.26e-14  3.60e-04    45s
#    5  -1.32280638e+00 -1.33737638e+00  5.78e-07 1.52e-14  6.13e-05    52s
#    6  -1.32568360e+00 -1.33181800e+00  2.54e-07 1.87e-14  2.58e-05    59s
#
# Barrier performed 6 iterations in 59.69 seconds (140.94 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5182   -1.3281076e+00   0.000000e+00   1.777184e-03     62s
# Extra simplex iterations after uncrush: 12
#     5194   -1.3281770e+00   0.000000e+00   0.000000e+00     62s
#
# Solved in 5194 iterations and 62.00 seconds (74.06 work units)
# Optimal objective -1.328176981e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25039234 nonzeros
# Model fingerprint: 0xbf7870bb
# Coefficient statistics:
#   Matrix range     [1e-13, 5e+00]
#   Objective range  [2e-11, 1e-02]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2400 rows and 762 columns (presolve time = 6s) ...
# Presolve removed 6006 rows and 762 columns
# Presolve time: 8.56s
# Presolved: 3606 rows, 7650 columns, 11803211 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 6.500e+06
#  Factor NZ  : 6.503e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.564e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.35376141e-01 -4.06571702e+03  1.34e+02 1.42e-14  2.55e+01    17s
#    1   3.58924233e-04 -2.89450169e+02  2.83e+00 7.11e-14  1.27e+00    24s
#    2  -8.14487571e-02 -9.54000445e+00  7.23e-03 4.97e-14  3.96e-02    31s
#    3  -9.11052544e-01 -1.74295157e+00  1.27e-04 5.68e-14  3.48e-03    38s
#    4  -1.10935788e+00 -1.56474210e+00  7.37e-05 1.99e-13  1.90e-03    45s
#    5  -1.25004265e+00 -1.41787639e+00  2.97e-05 2.84e-14  7.02e-04    52s
#
# Barrier performed 5 iterations in 55.15 seconds (125.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 11
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4731   -1.3563468e+00   0.000000e+00   0.000000e+00     57s
#
# Solved in 4731 iterations and 57.45 seconds (66.74 work units)
# Optimal objective -1.356346840e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25092298 nonzeros
# Model fingerprint: 0xaeb32059
# Coefficient statistics:
#   Matrix range     [1e-13, 1e-01]
#   Objective range  [2e-11, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2970 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 2970 rows and 762 columns (presolve time = 10s) ...
# Presolve removed 6291 rows and 762 columns
# Presolve time: 12.34s
# Presolved: 3321 rows, 7365 columns, 11262524 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 5.513e+06
#  Factor NZ  : 5.516e+06 (roughly 50 MB of memory)
#  Factor Ops : 1.221e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.25743036e+00 -2.86505561e+04  3.53e+01 1.42e-14  1.82e+01    20s
#
# Barrier performed 0 iterations in 23.63 seconds (40.93 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1699   -5.9724325e-01   0.000000e+00   1.117543e-03     25s
# Extra simplex iterations after uncrush: 11
#     1710   -5.9728690e-01   0.000000e+00   0.000000e+00     26s
#
# Solved in 1710 iterations and 25.62 seconds (22.17 work units)
# Optimal objective -5.972869043e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25091406 nonzeros
# Model fingerprint: 0x782187db
# Coefficient statistics:
#   Matrix range     [1e-13, 1e-01]
#   Objective range  [6e-12, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3100 rows and 761 columns (presolve time = 7s) ...
# Presolve removed 3100 rows and 761 columns (presolve time = 11s) ...
# Presolve removed 6356 rows and 761 columns
# Presolve time: 12.14s
# Presolved: 3256 rows, 7301 columns, 11113057 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 5.299e+06
#  Factor NZ  : 5.302e+06 (roughly 50 MB of memory)
#  Factor Ops : 1.151e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.08180748e-02 -1.33585894e+03  7.39e+01 4.26e-14  1.35e+01    20s
#
# Barrier performed 0 iterations in 23.84 seconds (39.98 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1844   -6.3598811e-01   0.000000e+00   1.070803e-03     26s
# Extra simplex iterations after uncrush: 9
#     1853   -6.3602994e-01   0.000000e+00   0.000000e+00     26s
#
# Solved in 1853 iterations and 25.80 seconds (22.54 work units)
# Optimal objective -6.360299377e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25092858 nonzeros
# Model fingerprint: 0xd1f47cab
# Coefficient statistics:
#   Matrix range     [1e-13, 2e-01]
#   Objective range  [6e-11, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3022 rows and 759 columns (presolve time = 7s) ...
# Presolve removed 3022 rows and 759 columns (presolve time = 10s) ...
# Presolve removed 6317 rows and 759 columns
# Presolve time: 12.37s
# Presolved: 3295 rows, 7342 columns, 11206172 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 5.427e+06
#  Factor NZ  : 5.430e+06 (roughly 50 MB of memory)
#  Factor Ops : 1.193e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.99559300e-01 -3.40106081e+02  6.00e+01 7.11e-15  6.44e+00    20s
#
# Barrier performed 0 iterations in 25.17 seconds (40.57 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 13
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2068   -7.4366804e-01   0.000000e+00   0.000000e+00     27s
#
# Solved in 2068 iterations and 27.11 seconds (24.26 work units)
# Optimal objective -7.436680438e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25093722 nonzeros
# Model fingerprint: 0x78300022
# Coefficient statistics:
#   Matrix range     [1e-13, 4e-01]
#   Objective range  [6e-10, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2148 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 5880 rows and 762 columns
# Presolve time: 8.98s
# Presolved: 3732 rows, 7776 columns, 12034358 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 6.962e+06
#  Factor NZ  : 6.966e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.733e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.24837034e-02 -2.31862009e+03  7.73e+01 7.11e-15  1.50e+01    18s
#    1  -1.79691679e-02 -1.78750094e+02  2.23e+00 7.11e-14  7.79e-01    25s
#    2  -1.13261646e-01 -8.76619988e+00  8.53e-13 4.26e-14  3.56e-02    33s
#    3  -5.62722771e-01 -3.23382347e+00  2.86e-12 2.13e-14  1.10e-02    40s
#    4  -1.17424321e+00 -1.50132115e+00  1.10e-11 1.07e-14  1.35e-03    47s
#    5  -1.24141658e+00 -1.39404690e+00  1.05e-11 2.40e-14  6.28e-04    54s
#    6  -1.30624705e+00 -1.32220416e+00  1.78e-11 1.55e-14  6.57e-05    62s
#    7  -1.31004813e+00 -1.31786914e+00  5.08e-11 1.19e-14  3.22e-05    69s
#    8  -1.31171007e+00 -1.31405381e+00  6.57e-11 1.12e-14  9.64e-06    76s
#    9  -1.31290207e+00 -1.31307591e+00  1.53e-10 1.84e-14  7.15e-07    84s
#   10  -1.31293658e+00 -1.31296681e+00  9.09e-10 1.63e-14  1.24e-07    91s
#
# Barrier performed 10 iterations in 94.84 seconds (215.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7187   -1.3129483e+00   0.000000e+00   1.028691e-03     97s
# Extra simplex iterations after uncrush: 6
#     7193   -1.3129885e+00   0.000000e+00   0.000000e+00     97s
#
# Solved in 7193 iterations and 96.97 seconds (118.71 work units)
# Optimal objective -1.312988509e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9612 rows, 4806 columns and 25093030 nonzeros
# Model fingerprint: 0x9d355b84
# Coefficient statistics:
#   Matrix range     [1e-13, 5e-01]
#   Objective range  [1e-10, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2156 rows and 762 columns (presolve time = 6s) ...
# Presolve removed 5884 rows and 762 columns
# Presolve time: 8.91s
# Presolved: 3728 rows, 7772 columns, 12037044 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 6.947e+06
#  Factor NZ  : 6.951e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.728e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  
+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.61826307e+00 -2.34503430e+04  8.32e+01 1.42e-14  3.60e+01    18s
#    1  -1.31637120e-02 -1.65563794e+03  5.37e-01 7.11e-14  1.72e+00    26s
#    2  -1.88609278e-02 -2.50221781e+01  1.42e-12 5.68e-14  2.56e-02    33s
#    3  -4.88405260e-01 -2.11847094e+00  6.88e-12 1.14e-13  1.67e-03    40s
#    4  -9.97936520e-01 -1.73226820e+00  3.43e-11 1.14e-13  7.51e-04    48s
#    5  -1.22083862e+00 -1.51618624e+00  4.18e-11 4.26e-14  3.02e-04    55s
#    6  -1.38256824e+00 -1.41436118e+00  1.20e-10 1.42e-14  3.25e-05    63s
#    7  -1.38916112e+00 -1.40774295e+00  1.38e-10 7.11e-15  1.90e-05    70s
#    8  -1.39866991e+00 -1.40288287e+00  4.02e-10 4.33e-15  4.31e-06    78s
#    9  -1.40121210e+00 -1.40167121e+00  8.09e-10 4.50e-15  4.69e-07    86s
#
# Barrier performed 9 iterations in 88.85 seconds (203.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6323   -1.4014569e+00   0.000000e+00   7.118591e-04     91s
# Extra simplex iterations after uncrush: 11
#     6334   -1.4015125e+00   0.000000e+00   0.000000e+00     91s
#
# Solved in 6334 iterations and 90.88 seconds (111.32 work units)
# Optimal objective -1.401512518e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25096874 nonzeros
# Model fingerprint: 0x6b6e310c
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+00]
#   Objective range  [4e-11, 1e-02]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2230 rows and 795 columns (presolve time = 6s) ...
# Presolve removed 5951 rows and 795 columns
# Presolve time: 8.60s
# Presolved: 3721 rows, 7762 columns, 12024824 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 6.921e+06
#  Factor NZ  : 6.925e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.718e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.09503529e-01 -4.13278341e+03  2.99e+01 7.11e-15  2.56e+01    18s
#    1  -1.19365208e-02 -3.00830184e+02  3.28e-01 6.39e-14  1.27e+00    25s
#    2  -8.45923936e-02 -8.69978336e+00  1.72e-03 7.11e-14  3.55e-02    32s
#    3  -8.26932871e-01 -1.68637038e+00  7.88e-05 3.38e-14  3.54e-03    39s
#    4  -1.16956207e+00 -1.35420957e+00  1.15e-05 2.84e-14  7.61e-04    47s
#    5  -1.25072399e+00 -1.26669606e+00  2.58e-07 1.14e-13  6.58e-05    54s
#    6  -1.25585992e+00 -1.26041467e+00  7.27e-08 2.84e-14  1.88e-05    61s
#    7  -1.25744875e+00 -1.25878745e+00  2.05e-08 2.20e-14  5.52e-06    69s
#    8  -1.25783176e+00 -1.25835862e+00  1.05e-08 2.03e-14  2.17e-06    76s
#    9  -1.25817933e+00 -1.25820965e+00  9.79e-09 3.35e-14  1.25e-07    83s
#
# Barrier performed 9 iterations in 86.50 seconds (199.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 10
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6695   -1.2582452e+00   0.000000e+00   0.000000e+00     89s
#
# Solved in 6695 iterations and 88.51 seconds (107.20 work units)
# Optimal objective -1.258245223e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25362220 nonzeros
# Model fingerprint: 0xd54a08ef
# Coefficient statistics:
#   Matrix range     [1e-13, 2e+01]
#   Objective range  [3e-12, 1e-02]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2174 rows and 756 columns (presolve time = 6s) ...
# Presolve removed 5923 rows and 756 columns
# Presolve time: 8.48s
# Presolved: 3749 rows, 7829 columns, 12161289 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 7.026e+06
#  Factor NZ  : 7.029e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.757e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.62949685e+00 -3.24209169e+05  8.32e+01 0.00e+00  3.11e+01    18s
#    1  -1.57835594e-01 -2.33415320e+04  1.34e+00 7.11e-14  1.54e+00    25s
#    2  -9.46403756e-04 -1.00275448e+02  1.76e-03 7.11e-14  6.41e-03    32s
#    3  -3.16399098e-01 -2.94831248e+00  6.33e-06 5.68e-14  1.68e-04    39s
#    4  -1.09573077e+00 -1.42712604e+00  5.51e-07 2.66e-14  2.12e-05    47s
#    5  -1.26529373e+00 -1.29962702e+00  1.96e-08 1.42e-14  2.19e-06    55s
#    6  -1.27764204e+00 -1.28876148e+00  5.65e-09 8.88e-16  7.10e-07    62s
#    7  -1.28240972e+00 -1.28510519e+00  2.34e-09 3.55e-15  1.72e-07    69s
#    8  -1.28381206e+00 -1.28444365e+00  6.98e-09 3.55e-15  4.03e-08    77s
#    9  -1.28418750e+00 -1.28428435e+00  9.25e-09 1.42e-14  6.19e-09    84s
#
# Barrier performed 9 iterations in 89.24 seconds (201.79 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6751   -1.2842449e+00   0.000000e+00   1.509644e-03     91s
# Extra simplex iterations after uncrush: 9
#     6760   -1.2842925e+00   0.000000e+00   0.000000e+00     91s
#
# Solved in 6760 iterations and 91.35 seconds (111.18 work units)
# Optimal objective -1.284292525e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25578326 nonzeros
# Model fingerprint: 0x0c5bd611
# Coefficient statistics:
#   Matrix range     [1e-13, 1e-01]
#   Objective range  [8e-13, 8e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3656 rows and 757 columns (presolve time = 7s) ...
# Presolve removed 3656 rows and 757 columns (presolve time = 10s) ...
# Presolve removed 6664 rows and 757 columns
# Presolve time: 11.77s
# Presolved: 3008 rows, 7087 columns, 10642669 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 4.523e+06
#  Factor NZ  : 4.526e+06 (roughly 40 MB of memory)
#  Factor Ops : 9.077e+09 (roughly 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 16.20 seconds (17.68 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 9
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      594   -2.4701091e-01   0.000000e+00   0.000000e+00     18s
#
# Solved in 594 iterations and 18.11 seconds (14.09 work units)
# Optimal objective -2.470109082e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25571098 nonzeros
# Model fingerprint: 0x3be52a96
# Coefficient statistics:
#   Matrix range     [1e-13, 1e-01]
#   Objective range  [8e-12, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3676 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 3676 rows and 762 columns (presolve time = 11s) ...
# Presolve removed 6674 rows and 762 columns
# Presolve time: 12.04s
# Presolved: 2998 rows, 7072 columns, 10624264 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 4.493e+06
#  Factor NZ  : 4.496e+06 (roughly 40 MB of memory)
#  Factor Ops : 8.987e+09 (roughly 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 16.55 seconds (17.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 13
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      703   -3.2416887e-01   0.000000e+00   0.000000e+00     19s
#
# Solved in 703 iterations and 18.62 seconds (14.41 work units)
# Optimal objective -3.241688731e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25584124 nonzeros
# Model fingerprint: 0xfb3a9d27
# Coefficient statistics:
#   Matrix range     [1e-13, 1e-01]
#   Objective range  [2e-12, 1e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3318 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 3318 rows and 762 columns (presolve time = 10s) ...
# Presolve removed 6495 rows and 762 columns
# Presolve time: 12.29s
# Presolved: 3177 rows, 7251 columns, 11082398 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 5.045e+06
#  Factor NZ  : 5.048e+06 (roughly 45 MB of memory)
#  Factor Ops : 1.069e+10 (roughly 2 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.78498932e+00 -2.63286081e+04  8.62e+01 7.11e-15  9.51e+00    17s
#
# Barrier performed 0 iterations in 18.08 seconds (24.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 10
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      842   -3.2121893e-01   0.000000e+00   0.000000e+00     20s
#
# Solved in 842 iterations and 20.01 seconds (15.60 work units)
# Optimal objective -3.212189323e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25585202 nonzeros
# Model fingerprint: 0x266702ff
# Coefficient statistics:
#   Matrix range     [1e-13, 7e-01]
#   Objective range  [1e-09, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2070 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 5871 rows and 762 columns
# Presolve time: 9.30s
# Presolved: 3801 rows, 7875 columns, 12317650 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 7.222e+06
#  Factor NZ  : 7.226e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.831e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -4.02736658e-01 -1.24125917e+04  7.33e+01 7.11e-15  1.89e+01    19s
#    1  -3.21900774e-02 -8.73706094e+02  1.96e+00 4.97e-14  9.38e-01    26s
#    2  -2.90256914e-02 -2.21138103e+01  7.14e-03 3.77e-13  2.25e-02    34s
#    3  -6.09919441e-01 -2.79226553e+00  6.22e-04 2.75e-14  2.22e-03    41s
#    4  -1.29495369e+00 -1.62169790e+00  3.56e-05 2.84e-14  3.32e-04    49s
#    5  -1.42930580e+00 -1.49117379e+00  4.16e-06 2.13e-14  6.29e-05    57s
#    6  -1.45699142e+00 -1.46236846e+00  1.20e-07 2.84e-14  5.46e-06    65s
#    7  -1.45840299e+00 -1.46072813e+00  5.98e-08 7.11e-15  2.36e-06    72s
#    8  -1.45935018e+00 -1.46016250e+00  1.99e-08 7.11e-15  8.25e-07    80s
#    9  -1.45977065e+00 -1.45983641e+00  1.91e-09 3.91e-15  6.68e-08    88s
#   10  -1.45980267e+00 -1.45981543e+00  7.93e-09 5.58e-15  1.30e-08    95s
#   11  -1.45980833e+00 -1.45981067e+00  3.02e-08 7.11e-15  2.38e-09   103s
#   12  -1.45980910e+00 -1.45980923e+00  7.19e-08 7.11e-15  1.34e-10   110s
#   13  -1.45980919e+00 -1.45980920e+00  3.51e-09 6.19e-15  3.12e-12   118s
#
# Barrier solved model in 13 iterations and 118.22 seconds (260.97 work units)
# Optimal objective -1.45980919e+00
#
# Crossover log...
#
#      327 DPushes remaining with DInf 0.0000000e+00               119s
#       39 DPushes remaining with DInf 0.0000000e+00               120s
#        0 DPushes remaining with DInf 0.0000000e+00               121s
#
#        5 PPushes remaining with PInf 0.0000000e+00               121s
#        0 PPushes remaining with PInf 0.0000000e+00               121s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.5061084e-13    121s
#
#
# Solved with barrier
# Extra simplex iterations after uncrush: 12
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      347   -1.4598426e+00   0.000000e+00   0.000000e+00    124s
#
# Solved in 347 iterations and 124.42 seconds (265.40 work units)
# Optimal objective -1.459842628e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25585296 nonzeros
# Model fingerprint: 0xc7e73a4b
# Coefficient statistics:
#   Matrix range     [1e-13, 5e-01]
#   Objective range  [2e-09, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 1906 rows and 762 columns (presolve time = 7s) ...
# Presolve removed 5789 rows and 762 columns
# Presolve time: 9.26s
# Presolved: 3883 rows, 7957 columns, 12466767 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 7.537e+06
#  Factor NZ  : 7.541e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.952e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.77652900e+00 -6.63786554e+04  1.30e+02 0.00e+00  2.50e+01    19s
#    1   2.75112344e-02 -4.66382147e+03  2.80e+00 4.80e-14  1.23e+00    27s
#    2  -4.98132609e-03 -7.07725399e+01  9.22e-03 4.97e-14  1.78e-02    34s
#    3  -4.32728564e-01 -4.45445220e+00  1.04e-03 1.14e-13  1.01e-03    42s
#    4  -1.27384765e+00 -1.85308301e+00  1.07e-04 2.13e-14  1.46e-04    50s
#    5  -1.40971036e+00 -1.67034656e+00  5.20e-05 1.07e-14  6.55e-05    58s
#    6  -1.53391327e+00 -1.55692163e+00  5.72e-07 2.13e-14  5.78e-06    66s
#    7  -1.53946945e+00 -1.54973440e+00  2.38e-07 7.11e-15  2.58e-06    74s
#    8  -1.54340910e+00 -1.54448357e+00  9.78e-09 8.26e-16  2.70e-07    82s
#    9  -1.54377641e+00 -1.54403505e+00  2.96e-09 7.11e-15  6.50e-08    89s
#   10  -1.54387159e+00 -1.54390659e+00  6.03e-09 9.51e-16  8.80e-09    97s
#   11  -1.54388095e+00 -1.54388833e+00  1.21e-08 1.07e-15  1.85e-09   105s
#   12  -1.54388296e+00 -1.54388338e+00  1.52e-09 7.11e-15  1.05e-10   114s
#   13  -1.54388302e+00 -1.54388308e+00  2.13e-10 1.42e-14  1.52e-11   121s
#   14  -1.54388304e+00 -1.54388304e+00  8.53e-10 7.11e-15  2.75e-13   129s
#
# Barrier solved model in 14 iterations and 129.48 seconds (287.33 work units)
# Optimal objective -1.54388304e+00
#
# Crossover log...
#
#      364 DPushes remaining with DInf 0.0000000e+00               130s
#        0 DPushes remaining with DInf 0.0000000e+00               132s
#
#        4 PPushes remaining with PInf 0.0000000e+00               132s
#        0 PPushes remaining with PInf 0.0000000e+00               133s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0547735e-13    133s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      371   -1.5438830e+00   0.000000e+00   9.829148e-04    135s
# Extra simplex iterations after uncrush: 12
#      383   -1.5439214e+00   0.000000e+00   0.000000e+00    136s
#
# Solved in 383 iterations and 135.87 seconds (292.47 work units)
# Optimal objective -1.543921432e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9672 rows, 4836 columns and 25584918 nonzeros
# Model fingerprint: 0x6e1d263f
# Coefficient statistics:
#   Matrix range     [1e-13, 8e-01]
#   Objective range  [6e-11, 3e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2106 rows and 761 columns (presolve time = 7s) ...
# Presolve removed 5889 rows and 761 columns
# Presolve time: 9.19s
# Presolved: 3783 rows, 7858 columns, 12299546 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.08s
#
# Barrier statistics:
#  AA' NZ     : 7.154e+06
#  Factor NZ  : 7.157e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.805e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -9.90276099e+00 -1.53171305e+05  1.34e+02 7.11e-15  2.92e+01    19s
#    1  -3.27739077e-02 -1.06247666e+04  4.18e-01 5.68e-14  1.36e+00    26s
#    2  -3.38065103e-03 -1.99353138e+01  1.36e-12 3.55e-14  2.54e-03    33s
#    3  -6.70666048e-01 -1.99347154e+00  4.42e-12 8.53e-14  1.68e-04    41s
#    4  -1.32825934e+00 -1.58559609e+00  5.22e-11 2.58e-14  3.27e-05    49s
#    5  -1.47381548e+00 -1.50180303e+00  7.25e-11 7.99e-15  3.56e-06    56s
#    6  -1.48447520e+00 -1.48726289e+00  1.18e-10 7.11e-15  3.55e-07    64s
#    7  -1.48542726e+00 -1.48561421e+00  7.75e-10 7.11e-15  2.38e-08    72s
#    8  -1.48547146e+00 -1.48552101e+00  4.39e-09 5.55e-16  6.31e-09    79s
#    9  -1.48548302e+00 -1.48548909e+00  6.64e-09 7.11e-15  7.73e-10    87s
#   10  -1.48548414e+00 -1.48548452e+00  3.08e-08 3.55e-15  4.89e-11    94s
#   11  -1.48548420e+00 -1.48548422e+00  4.36e-08 8.88e-16  1.85e-12   101s
#
# Barrier solved model in 11 iterations and 101.31 seconds (225.20 work units)
# Optimal objective -1.48548420e+00
#
# Crossover log...
#
#      334 DPushes remaining with DInf 0.0000000e+00               102s
#        0 DPushes remaining with DInf 0.0000000e+00               104s
#
#        9 PPushes remaining with PInf 0.0000000e+00               104s
#        0 PPushes remaining with PInf 0.0000000e+00               104s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.4252994e-14    104s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      346   -1.4854842e+00   0.000000e+00   6.608113e-04    107s
# Extra simplex iterations after uncrush: 11
#      357   -1.4855358e+00   0.000000e+00   0.000000e+00    107s
#
# Solved in 357 iterations and 106.92 seconds (229.46 work units)
# Optimal objective -1.485535833e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9732 rows, 4866 columns and 25262922 nonzeros
# Model fingerprint: 0x38b5bfff
# Coefficient statistics:
#   Matrix range     [1e-13, 5e+00]
#   Objective range  [8e-11, 1e-02]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2368 rows and 833 columns (presolve time = 6s) ...
# Presolve removed 6050 rows and 833 columns
# Presolve time: 8.68s
# Presolved: 3682 rows, 7715 columns, 12048257 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 6.777e+06
#  Factor NZ  : 6.780e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.665e+10 (roughly 4 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3.86048962e-01 -1.27978884e+03  8.37e+01 7.11e-15  1.59e+01    17s
#    1  -3.85891814e-02 -9.62748095e+01  1.73e+00 5.51e-14  8.35e-01    24s
#    2  -2.74947622e-01 -5.77863861e+00  6.36e-03 1.35e-13  4.57e-02    31s
#    3  -1.15861304e+00 -1.75760263e+00  3.04e-04 3.91e-14  4.97e-03    39s
#    4  -1.40158804e+00 -1.47168137e+00  5.07e-06 1.14e-13  5.81e-04    46s
#    5  -1.41610685e+00 -1.44965285e+00  2.23e-06 7.11e-14  2.78e-04    53s
#    6  -1.42603326e+00 -1.43371967e+00  3.55e-07 5.60e-14  6.38e-05    60s
#    7  -1.42871154e+00 -1.42912517e+00  1.43e-09 4.29e-14  3.43e-06    68s
#    8  -1.42882027e+00 -1.42889612e+00  4.71e-09 5.53e-14  6.29e-07    75s
#
# Barrier performed 8 iterations in 77.79 seconds (182.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 11
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6358   -1.4288999e+00   0.000000e+00   0.000000e+00     80s
#
# Solved in 6358 iterations and 79.88 seconds (97.90 work units)
# Optimal objective -1.428899874e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 9732 rows, 4866 columns and 25706186 nonzeros
# Model fingerprint: 0xc09d06b9
# Coefficient statistics:
#   Matrix range     [1e-13, 5e+00]
#   Objective range  [7e-11, 1e-02]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2374 rows and 747 columns (presolve time = 6s) ...
# ...
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36530746 nonzeros
# Model fingerprint: 0x4438cc92
# Coefficient statistics:
#   Matrix range     [1e-13, 9e-02]
#   Objective range  [1e-10, 1e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2992 rows and 737 columns (presolve time = 10s) ...
# Presolve removed 2992 rows and 737 columns (presolve time = 15s) ...
# Presolve removed 6952 rows and 737 columns
# Presolve time: 18.55s
# Presolved: 3960 rows, 8679 columns, 16467551 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 7.839e+06
#  Factor NZ  : 7.843e+06 (roughly 70 MB of memory)
#  Factor Ops : 2.071e+10 (roughly 6 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.02369915e-01 -2.56524547e+03  5.58e+01 1.42e-14  1.10e+01    32s
#
# Barrier performed 0 iterations in 41.45 seconds (69.61 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 15
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2417   -7.1732935e-01   0.000000e+00   0.000000e+00     44s
#
# Solved in 2417 iterations and 44.28 seconds (39.84 work units)
# Optimal objective -7.173293505e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36542478 nonzeros
# Model fingerprint: 0xdccfdba0
# Coefficient statistics:
#   Matrix range     [1e-13, 9e-02]
#   Objective range  [2e-10, 9e-04]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 3026 rows and 750 columns (presolve time = 10s) ...
# Presolve removed 3026 rows and 750 columns (presolve time = 15s) ...
# Presolve removed 6969 rows and 750 columns
# Presolve time: 18.29s
# Presolved: 3943 rows, 8649 columns, 16405646 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 7.772e+06
#  Factor NZ  : 7.776e+06 (roughly 70 MB of memory)
#  Factor Ops : 2.044e+10 (roughly 3 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -6.45416989e-01 -1.70911100e+03  8.40e+01 1.42e-14  1.45e+01    27s
#    1  -2.91022385e-02 -2.97999887e+02  2.21e+00 1.07e-13  1.19e+00    33s
#    2  -2.47801758e-02 -9.48510619e+00  4.49e-03 7.96e-13  3.50e-02    39s
#
# Barrier performed 2 iterations in 40.50 seconds (68.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 5
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2508   -7.4392974e-01   0.000000e+00   0.000000e+00     43s
#
# Solved in 2508 iterations and 43.36 seconds (40.48 work units)
# Optimal objective -7.439297360e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36532102 nonzeros
# Model fingerprint: 0x43c9d6b5
# Coefficient statistics:
#   Matrix range     [1e-13, 8e-02]
#   Objective range  [1e-10, 1e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2972 rows and 743 columns (presolve time = 10s) ...
# Presolve removed 2972 rows and 743 columns (presolve time = 15s) ...
# Presolve removed 6942 rows and 743 columns
# Presolve time: 18.71s
# Presolved: 3970 rows, 8683 columns, 16475721 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 7.878e+06
#  Factor NZ  : 7.882e+06 (roughly 70 MB of memory)
#  Factor Ops : 2.086e+10 (roughly 6 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.73842923e-01 -4.19442314e+03  6.34e+01 1.42e-14  8.79e+00    32s
#    1  -2.90434897e-03 -7.06631885e+02  1.52e+00 8.53e-14  6.97e-01    43s
#
# Barrier performed 1 iterations in 42.94 seconds (70.02 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2631   -8.8247354e-01   0.000000e+00   4.171040e-04     45s
# Extra simplex iterations after uncrush: 12
#     2643   -8.8248983e-01   0.000000e+00   0.000000e+00     46s
#
# Solved in 2643 iterations and 45.73 seconds (41.93 work units)
# Optimal objective -8.824898318e-01
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36546914 nonzeros
# Model fingerprint: 0x6e0f503d
# Coefficient statistics:
#   Matrix range     [1e-13, 6e-01]
#   Objective range  [6e-11, 2e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 1934 rows and 761 columns (presolve time = 5s) ...
# Presolve removed 1934 rows and 761 columns (presolve time = 10s) ...
# Presolve removed 6423 rows and 761 columns
# Presolve time: 13.93s
# Presolved: 4489 rows, 9184 columns, 17747633 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.10s
#
# Barrier statistics:
#  AA' NZ     : 1.007e+07
#  Factor NZ  : 1.008e+07 (roughly 90 MB of memory)
#  Factor Ops : 3.016e+10 (roughly 7 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -3.75859422e-01 -1.30210725e+04  2.37e+02 7.11e-15  3.40e+01    30s
#    1  -9.08034217e-02 -8.90383427e+02  6.52e+00 6.66e-14  1.66e+00    43s
#    2  -7.04959570e-02 -2.08777423e+01  7.52e-03 1.28e-13  3.63e-02    56s
#    3  -1.36219402e+00 -3.12000164e+00  6.89e-05 4.26e-14  3.06e-03    69s
#    4  -2.27138381e+00 -2.49942821e+00  3.18e-06 3.91e-14  3.97e-04    82s
#    5  -2.37956018e+00 -2.40373156e+00  2.43e-08 1.44e-14  4.21e-05    96s
#    6  -2.38743015e+00 -2.38962235e+00  1.42e-09 1.65e-14  3.82e-06   109s
#    7  -2.38793287e+00 -2.38901880e+00  4.66e-09 1.33e-14  1.89e-06   122s
#    8  -2.38812963e+00 -2.38867133e+00  5.31e-09 1.15e-14  9.44e-07   135s
#    9  -2.38828922e+00 -2.38836818e+00  9.30e-09 2.00e-14  1.38e-07   148s
#   10  -2.38832209e+00 -2.38832905e+00  3.51e-08 1.40e-14  1.21e-08   162s
#   11  -2.38832355e+00 -2.38832457e+00  7.00e-08 1.53e-14  1.78e-09   175s
#   12  -2.38832372e+00 -2.38832376e+00  1.06e-07 1.60e-14  6.64e-11   188s
#   13  -2.38832372e+00 -2.38832373e+00  9.87e-08 1.42e-14  1.42e-11   202s
#
# Barrier solved model in 13 iterations and 201.54 seconds (453.81 work units)
# Optimal objective -2.38832372e+00
#
# Crossover log...
#
#      574 DPushes remaining with DInf 0.0000000e+00               203s
#      267 DPushes remaining with DInf 0.0000000e+00               206s
#        0 DPushes remaining with DInf 0.0000000e+00               209s
#
#       20 PPushes remaining with PInf 1.2147160e-06               210s
#        0 PPushes remaining with PInf 0.0000000e+00               210s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.9327908e-04    210s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      597   -2.3883237e+00   0.000000e+00   9.932791e-04    211s
#
# Solved with barrier
#      598   -2.3883237e+00   0.000000e+00   8.776946e-04    215s
# Extra simplex iterations after uncrush: 3
#      601   -2.3883580e+00   0.000000e+00   0.000000e+00    216s
#
# Solved in 601 iterations and 216.13 seconds (467.35 work units)
# Optimal objective -2.388358009e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36546906 nonzeros
# Model fingerprint: 0xf71dac25
# Coefficient statistics:
#   Matrix range     [2e-13, 6e-01]
#   Objective range  [1e-10, 3e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2014 rows and 762 columns (presolve time = 5s) ...
# Presolve removed 2014 rows and 762 columns (presolve time = 10s) ...
# Presolve removed 6463 rows and 762 columns
# Presolve time: 13.89s
# Presolved: 4449 rows, 9143 columns, 17660932 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 9.895e+06
#  Factor NZ  : 9.899e+06 (roughly 80 MB of memory)
#  Factor Ops : 2.936e+10 (roughly 7 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.18433123e+00 -8.82670689e+03  1.72e+02 7.11e-15  2.32e+01    30s
#    1  -1.92682882e-01 -6.08154809e+02  8.91e+00 4.97e-14  1.19e+00    42s
#    2  -8.78136673e-02 -2.05321133e+01  6.89e-02 5.68e-14  3.60e-02    55s
#    3  -1.42039870e+00 -3.08994419e+00  5.96e-04 3.55e-14  2.92e-03    68s
#    4  -2.21163734e+00 -2.40440759e+00  2.36e-05 2.84e-14  3.37e-04    82s
#    5  -2.30705686e+00 -2.32695424e+00  3.38e-07 1.07e-14  3.48e-05    95s
#    6  -2.31410182e+00 -2.31676833e+00  2.61e-08 1.42e-14  4.67e-06   108s
#    7  -2.31483502e+00 -2.31595725e+00  8.83e-09 1.42e-14  1.96e-06   121s
#    8  -2.31508717e+00 -2.31566687e+00  4.99e-09 1.42e-14  1.01e-06   134s
#    9  -2.31521599e+00 -2.31544228e+00  6.56e-09 1.42e-14  3.96e-07   147s
#   10  -2.31524432e+00 -2.31530976e+00  7.01e-09 8.88e-15  1.15e-07   160s
#   11  -2.31526315e+00 -2.31527061e+00  2.63e-08 1.42e-14  1.30e-08   173s
#   12  -2.31526574e+00 -2.31526625e+00  6.03e-08 1.31e-14  8.80e-10   186s
#   13  -2.31526584e+00 -2.31526586e+00  2.39e-07 1.42e-14  1.31e-11   198s
#   14  -2.31526584e+00 -2.31526585e+00  2.34e-07 8.89e-15  1.24e-12   213s
#   15  -2.31526586e+00 -2.31526585e+00  2.29e-07 9.10e-15  3.12e-15   227s
#   16  -2.31526588e+00 -2.31526585e+00  4.70e-07 2.84e-14  3.12e-18   240s
#
# Barrier solved model in 16 iterations and 239.55 seconds (542.76 work units)
# Optimal objective -2.31526588e+00
#
# Crossover log...
#
#      517 DPushes remaining with DInf 0.0000000e+00               241s
#       28 DPushes remaining with DInf 0.0000000e+00               246s
#        0 DPushes remaining with DInf 0.0000000e+00               247s
#
#        0 PPushes remaining with PInf 0.0000000e+00               247s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.8853522e-12    247s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      520   -2.3152659e+00   0.000000e+00   5.057081e-04    251s
# Extra simplex iterations after uncrush: 5
#      525   -2.3152856e+00   0.000000e+00   0.000000e+00    252s
#
# Solved in 525 iterations and 251.52 seconds (554.08 work units)
# Optimal objective -2.315285609e+00
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Academic license - for non-commercial use only - registered to ppankaj21@iitk.ac.in
# Optimize a model with 10912 rows, 5456 columns and 36546860 nonzeros
# Model fingerprint: 0xd8261873
# Coefficient statistics:
#   Matrix range     [1e-13, 5e-01]
#   Objective range  [2e-11, 4e-03]
#   Bounds range     [1e-05, 1e+01]
#   RHS range        [1e-01, 1e-01]
# Presolve removed 2096 rows and 761 columns (presolve time = 10s) ...
# Presolve removed 2096 rows and 761 columns (presolve time = 11s) ...
# Presolve removed 6504 rows and 761 columns
# Presolve time: 13.75s
# Presolved: 4408 rows, 9103 columns, 17573477 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 9.713e+06
#  Factor NZ  : 9.717e+06 (roughly 80 MB of memory)
#  Factor Ops : 2.856e+10 (roughly 7 seconds per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.57578909e+00 -9.55678537e+03  1.36e+02 7.11e-15  2.52e+01    29s
#    1   2.70383400e-02 -6.75460804e+02  3.15e+00 5.68e-14  1.25e+00    42s
#    2  -7.93719194e-02 -1.60132084e+01  1.14e-02 5.68e-14  2.80e-02    54s
#    3  -1.51575830e+00 -2.72008518e+00  2.27e-04 4.62e-14  2.12e-03    67s
#    4  -2.13352426e+00 -2.28996844e+00  9.71e-06 3.02e-14  2.75e-04    81s
#    5  -2.17453852e+00 -2.23558379e+00  4.30e-06 8.94e-15  1.07e-04    93s
#    6  -2.20415151e+00 -2.21337106e+00  2.70e-07 1.42e-14  1.62e-05   106s
#    7  -2.20749237e+00 -2.20846361e+00  2.35e-08 1.04e-14  1.71e-06   119s
#    8  -2.20797510e+00 -2.20803590e+00  4.86e-09 8.44e-15  1.07e-07   133s
#    9  -2.20800170e+00 -2.20800728e+00  3.73e-08 1.36e-14  9.81e-09   146s
#   10  -2.20800391e+00 -2.20800463e+00  6.45e-08 1.10e-14  1.27e-09   158s
#   11  -2.20800409e+00 -2.20800413e+00  1.06e-07 9.10e-15  8.50e-11   172s
#   12  -2.20800411e+00 -2.20800411e+00  6.42e-09 1.40e-14  5.10e-12   185s
#
# Barrier solved model in 12 iterations and 185.18 seconds (415.80 work units)
# Optimal objective -2.20800411e+00
#
# Crossover log...
#
#      535 DPushes remaining with DInf 0.0000000e+00               186s
#       43 DPushes remaining with DInf 0.0000000e+00               191s
#        0 DPushes remaining with DInf 0.0000000e+00               192s
#
#        8 PPushes remaining with PInf 0.0000000e+00               192s
#        0 PPushes remaining with PInf 0.0000000e+00               192s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.8697648e-12    192s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      546   -2.2080041e+00   0.000000e+00   2.673024e-04    197s
# Extra simplex iterations after uncrush: 4
#      550   -2.2080250e+00   0.000000e+00   0.000000e+00    197s
#
# Solved in 550 iterations and 197.30 seconds (427.22 work units)
# Optimal objective -2.208024989e+00

# %%
# np.array(improved_loss).min()
# Out:
# 0.32981693744659424

# %%
# best_model = fine_tuned_models[np.array(improved_loss).argmin()]
